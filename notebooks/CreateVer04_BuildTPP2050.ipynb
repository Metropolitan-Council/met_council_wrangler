# %% [markdown]
# This notebook applies future scenario 2050 cards, save as scenario, output as .net

# %%
import os
import sys
import pandas as pd
import numpy as np

from pyproj import CRS
from pathlib import Path

from projectcard import read_cards

import network_wrangler
from network_wrangler import load_scenario
from network_wrangler import load_roadway   
from network_wrangler import load_transit
from network_wrangler import create_scenario
from network_wrangler import Scenario
from network_wrangler.roadway import write_roadway
from network_wrangler.transit import write_transit

from met_council_wrangler import MetCouncil_Parameters
from met_council_wrangler import metcouncil_roadway
from met_council_wrangler import metcouncil_transit

from cube_wrangler import Parameters
from cube_wrangler import util
from cube_wrangler import roadway
from cube_wrangler import StandardTransit

# %%
network_wrangler.setup_logging()

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # remote i/o

# %%
metcouncil_wrangler_dir = os.path.join(r"Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler")
cube_wrangler_dir = os.path.join(r"Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler")

cc_dir = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\standard_networks\v00\standard_networks")

net_dir = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks")
output_dir2 = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\output")

# %%
## base mnpass
project_card_dir1 = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\BaseMnPASS_v1")
## no build cards
project_card_dir2 = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\NoBuild_TPP2023_v1")
project_card_dir3 = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\NoBuild_MnPASS2023_v1")
## build scenario 
project_card_dir4 = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_TPP2050_v1")
project_card_dir5 = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_MnPASS2050_v1")
####temp space if needed
# project_card_dir6= os.path.join("C:/project_card_registry/projects/test")

# %%
metcouncil_parameters = MetCouncil_Parameters(
    metcouncil_wrangler_base_dir=metcouncil_wrangler_dir,
    cube_wrangler_base_dir=cube_wrangler_dir
)
# Out:
# 2024-12-13 22:28:41, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 22:28:41, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler

# %% [markdown]
# # Load Version03 standard networks

# %%
version_03_scenario = load_scenario(os.path.join(net_dir, 'v03', 'standard_networks', 'v03_scenario.yml'))
# Out:
# 2024-12-13 22:28:41, DEBUG: Loading Scenario from file: Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\v03_scenario.yml
# 2024-12-13 22:28:42, DEBUG: Reading nodes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\roadway\v03_node.geojson.
# 2024-12-13 22:28:42, DEBUG: Estimated read time: 4 seconds.
# 2024-12-13 22:29:01, DEBUG: Read 414326 nodes from file in 19.62.
# 2024-12-13 22:29:01, DEBUG: Turning node data into official nodes_df
# 2024-12-13 22:29:08, INFO: Read 414326 nodes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\roadway\v03_node.geojson in 26.5.
# 2024-12-13 22:29:09, INFO: Reading links from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\roadway\v03_link.json.
# 2024-12-13 22:29:09, DEBUG: Estimated read time: 4 minutes.
# 2024-12-13 22:30:22, DEBUG: Read 1061803 links in 73.81.
# 2024-12-13 22:30:22, DEBUG: Creating 1061803 links.
# 2024-12-13 22:30:23, DEBUG: Translating 240 records in lanes from v0 to v1 format.
# 2024-12-13 22:30:23, DEBUG: links_df.loc[complex_idx, prop]:
#                          1897    {'default': 0, 'timeofday': [{'value': 2, 'tim...
# 4912    {'default': 2, 'timeofday': [{'value': 1.0, 't...
# 6620    {'default': 4, 'timeofday': [{'value': 3.0, 't...
# 7850    {'default': 4, 'timeofday': [{'value': 3.0, 't...
# 9071    {'default': 5, 'timeofday': [{'value': 4.0, 't...
# Name: lanes, dtype: object
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 5.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 5.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:23, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 5.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 5.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 0.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 0.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 5.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 5.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 6.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 6.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 0.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 0.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 5.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 5.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2}
# 2024-12-13 22:30:24, DEBUG: Translating 231 records in ML_lanes from v0 to v1 format.
# 2024-12-13 22:30:24, DEBUG: links_df.loc[complex_idx, prop]:
#                          4912     {'default': 0, 'timeofday': [{'value': 1, 'tim...
# 6620     {'default': 0, 'timeofday': [{'value': 1, 'tim...
# 7850     {'default': 0, 'timeofday': [{'value': 1, 'tim...
# 9071     {'default': 0, 'timeofday': [{'value': 1, 'tim...
# 10374    {'default': 0, 'timeofday': [{'value': 1, 'tim...
# Name: ML_lanes, dtype: object
# 2024-12-13 22:30:24, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:24, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# ...
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 22:30:25, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 22:31:54, DEBUG: 1061803 new links.
# 2024-12-13 22:31:54, INFO: Read + transformed 1061803 links from             Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\roadway\v03_link.json in 165.64.
# 2024-12-13 22:32:07, INFO: Reading GTFS feed tables from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\transit
# 2024-12-13 22:32:07, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\transit\v03_frequencies.txt.
# 2024-12-13 22:32:07, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\transit\v03_routes.txt.
# 2024-12-13 22:32:07, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\transit\v03_shapes.txt.
# 2024-12-13 22:32:07, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\transit\v03_stops.txt.
# 2024-12-13 22:32:07, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\transit\v03_trips.txt.
# 2024-12-13 22:32:08, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\transit\v03_stop_times.txt.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\network_wrangler\transit\io.py:81: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file)
# 2024-12-13 22:32:08, INFO: Initializing frequencies
# 2024-12-13 22:32:08, DEBUG: Validating + coercing value to frequencies
# 2024-12-13 22:32:08, DEBUG: PK table trips for specified FK                     frequencies.trip_id not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 22:32:08, INFO: Initializing routes
# 2024-12-13 22:32:08, DEBUG: Validating + coercing value to routes
# 2024-12-13 22:32:08, DEBUG: PK table agencies for specified FK                     routes.agency_id not in table list - skipping validation.
# 2024-12-13 22:32:08, DEBUG: Referencing table trips not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:08, INFO: Initializing shapes
# 2024-12-13 22:32:08, DEBUG: Validating + coercing value to shapes
# 2024-12-13 22:32:08, INFO: Initializing stops
# 2024-12-13 22:32:08, DEBUG: Validating + coercing value to stops
# 2024-12-13 22:32:08, DEBUG: PK table stops for specified FK                     stops.parent_station not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 22:32:08, DEBUG: Referencing table stops not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:08, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:08, INFO: Initializing trips
# 2024-12-13 22:32:08, DEBUG: Validating + coercing value to trips
# 2024-12-13 22:32:08, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:08, INFO: Initializing stop_times
# 2024-12-13 22:32:08, DEBUG: Validating + coercing value to stop_times
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\engines\pandas_engine.py:873: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   col = to_datetime_fn(col, **self.to_datetime_kwargs)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\engines\pandas_engine.py:873: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   col = to_datetime_fn(col, **self.to_datetime_kwargs)
# 2024-12-13 22:32:08, DEBUG: Creating new TransitNetwork.
# 2024-12-13 22:32:14, INFO: Creating Scenario
# 2024-12-13 22:32:17, DEBUG: Validating + coercing value to frequencies
# 2024-12-13 22:32:17, DEBUG: PK table trips for specified FK                     frequencies.trip_id not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 22:32:17, DEBUG: Validating + coercing value to routes
# 2024-12-13 22:32:17, DEBUG: PK table agencies for specified FK                     routes.agency_id not in table list - skipping validation.
# 2024-12-13 22:32:17, DEBUG: Referencing table trips not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 22:32:17, DEBUG: Validating + coercing value to stops
# 2024-12-13 22:32:17, DEBUG: PK table stops for specified FK                     stops.parent_station not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 22:32:17, DEBUG: Referencing table stops not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:17, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:17, DEBUG: Validating + coercing value to trips
# 2024-12-13 22:32:17, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:17, DEBUG: Validating + coercing value to stop_times
# 2024-12-13 22:32:17, WARNING: Creating a deep copy of db object.            This will NOT update any references (e.g. from TransitNetwork)

# %%
version_03_scenario.road_net.links_df.columns
# Out:
# Index(['model_link_id', 'A', 'B', 'name', 'rail_only', 'bus_only',
#        'drive_access', 'bike_access', 'walk_access', 'distance', 'roadway',
#        'projects', 'managed', 'shape_id', 'lanes', 'price', 'ref', 'access',
#        'ML_projects', 'ML_lanes', 'ML_access', 'ML_access_point',
#        'ML_egress_point', 'osm_link_id', 'locationReferences',
#        'shstReferenceId', 'shstGeometryId', 'fromIntersectionId',
#        'toIntersectionId', 'u', 'v', 'nodeIds', 'wayId', 'roadClass', 'oneWay',
#        'roundabout', 'link', 'oneway', 'lanes_osm', 'highway', 'service',
#        'width', 'maxspeed', 'junction', 'bridge', 'tunnel', 'landuse', 'area',
#        'key', 'forward', 'backReferenceId', 'metadata', 'source', 'county',
#        'length', 'centroidconnect', 'assign_group', 'roadway_class',
#        'trn_priority', 'area_type', 'ramp_flag', 'bike', 'walk', 'MNPASS_CODE',
#        'MNPASS_PAY', 'ML_egress', 'ML_MNPASS_CODE', 'sc_lanes', 'sc_ML_lanes',
#        'geometry'],
#       dtype='object')

# %% [markdown]
# # Create Scenario 03

# %%
version_04_scenario = create_scenario(
    base_scenario=version_03_scenario,
    project_card_filepath = project_card_dir4 #Build_TPP2050
)
# Out:
# 2024-12-13 22:32:25, INFO: Creating Scenario
# 2024-12-13 22:32:26, DEBUG: Validating + coercing value to frequencies
# 2024-12-13 22:32:26, DEBUG: PK table trips for specified FK                     frequencies.trip_id not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 22:32:26, DEBUG: Validating + coercing value to routes
# 2024-12-13 22:32:26, DEBUG: PK table agencies for specified FK                     routes.agency_id not in table list - skipping validation.
# 2024-12-13 22:32:26, DEBUG: Referencing table trips not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:26, DEBUG: Validating + coercing value to shapes
# 2024-12-13 22:32:26, DEBUG: Validating + coercing value to stops
# 2024-12-13 22:32:26, DEBUG: PK table stops for specified FK                     stops.parent_station not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 22:32:26, DEBUG: Referencing table stops not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:26, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:26, DEBUG: Validating + coercing value to trips
# 2024-12-13 22:32:26, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 22:32:26, DEBUG: Validating + coercing value to stop_times
# 2024-12-13 22:32:26, WARNING: Creating a deep copy of db object.            This will NOT update any references (e.g. from TransitNetwork)
# 2024-12-13 22:32:35, INFO: Adding bluelineext to scenario.
# 2024-12-13 22:32:35, INFO: Adding cr12 to scenario.
# 2024-12-13 22:32:35, INFO: Adding cr7 to scenario.
# 2024-12-13 22:32:36, INFO: Adding dakota_cr46 to scenario.
# 2024-12-13 22:32:36, INFO: Adding goldline to scenario.
# 2024-12-13 22:32:36, INFO: Adding greenlineext to scenario.
# 2024-12-13 22:32:37, INFO: Adding hennepincr81basslakerdintchng to scenario.
# 2024-12-13 22:32:37, INFO: Adding mn13quentinnicolletaveintchngsedit to scenario.
# 2024-12-13 22:32:37, INFO: Adding mn252hwyconvaccessoption to scenario.
# 2024-12-13 22:32:38, INFO: Adding mn36mn120intchng to scenario.
# 2024-12-13 22:32:38, INFO: Adding mn5hennepincr4intchng to scenario.
# 2024-12-13 22:32:38, INFO: Adding mn610eastriverrd to scenario.
# 2024-12-13 22:32:38, INFO: Adding mn6585thst93stintchngs to scenario.
# 2024-12-13 22:32:39, INFO: Adding mn65bunkerlakerdintchng to scenario.
# 2024-12-13 22:32:39, INFO: Adding riverview network edits to scenario.
# 2024-12-13 22:32:39, INFO: Adding wbroadwayave85th93rd2to4lanes to scenario.

# %%
version_04_scenario.add_project_cards(
     list(
            read_cards(project_card_dir5).values() #Build_MnPASS2050
        )
)
# Out:
# 2024-12-13 22:32:41, INFO: Adding 35w north nb s2 managed lane to scenario.
# 2024-12-13 22:32:41, DEBUG: Adding ['add mnpass_code'] to 35w north nb s2 managed lane dependency table.
# 2024-12-13 22:32:42, INFO: Adding 35w north sb s2 managed lane to scenario.
# 2024-12-13 22:32:42, DEBUG: Adding ['add mnpass_code'] to 35w north sb s2 managed lane dependency table.
# 2024-12-13 22:32:42, INFO: Adding 494 eb segment 2 managed lane to scenario.
# 2024-12-13 22:32:42, DEBUG: Adding ['add mnpass_code'] to 494 eb segment 2 managed lane dependency table.
# 2024-12-13 22:32:42, INFO: Adding 494 wb segment 2 managed lane to scenario.
# 2024-12-13 22:32:42, DEBUG: Adding ['add mnpass_code'] to 494 wb segment 2 managed lane dependency table.
# 2024-12-13 22:32:43, INFO: Adding 94 nb s1 managed lane to scenario.
# 2024-12-13 22:32:43, DEBUG: Adding ['mn252hwyconvaccessoption'] to 94 nb s1 managed lane dependency table.
# 2024-12-13 22:32:43, INFO: Adding 94 sb s1 managed lane to scenario.
# 2024-12-13 22:32:43, DEBUG: Adding ['mn252hwyconvaccessoption'] to 94 sb s1 managed lane dependency table.

# %%
version_04_scenario.apply_all_projects()
# Out:
# 2024-12-13 22:32:44, DEBUG: Ordered Projects:
# deque(['494 wb segment 2 managed lane', '494 eb segment 2 managed lane', '35w north sb s2 managed lane', '35w north nb s2 managed lane', 'wbroadwayave85th93rd2to4lanes', 'riverview network edits', 'mn65bunkerlakerdintchng', 'mn6585thst93stintchngs', 'mn610eastriverrd', 'mn5hennepincr4intchng', 'mn36mn120intchng', 'mn252hwyconvaccessoption', '94 sb s1 managed lane', '94 nb s1 managed lane', 'mn13quentinnicolletaveintchngsedit', 'hennepincr81basslakerdintchng', 'greenlineext', 'goldline', 'dakota_cr46', 'cr7', 'cr12', 'bluelineext'])
# 2024-12-13 22:32:44, INFO: Applying 494 wb segment 2 managed lane from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_MnPASS2050_v1\494_WB_Seg2_MnPASS.yml
# 2024-12-13 22:32:44, DEBUG: types: ['roadway_property_change']
# 2024-12-13 22:32:44, DEBUG: type: roadway_property_change
# 2024-12-13 22:32:44, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:32:44, DEBUG: Getting selection from key: 099eed074b68cae108042c7b7032f6539b04ea13
# 2024-12-13 22:32:44, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [49605, 1750231, 216760, 232193, 300668, 347381, 385373, 1750230, 424003, 461882, 531091, 385831], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:32:48, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:32:48, DEBUG: Applying roadway property change project.
# 2024-12-13 22:32:52, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:32:52, INFO: Final selected links: 12
# 2024-12-13 22:32:56, DEBUG: prop_dict:
# {'change': 0, 'scoped': [{'change': -1, 'timespan': ['06:00', '10:00']}, {'change': -1, 'timespan': ['15:00', '19:00']}]}
# 2024-12-13 22:32:56, DEBUG: Editing lanes on links [49605, 216760, 232193, 300668, 347381, 385373, 385831, 424003, 461882, 531091, 1750230, 1750231]
# 2024-12-13 22:32:56, DEBUG: Data: {'change': -1, 'timespan': ['06:00', '10:00']}
# 2024-12-13 22:32:56, DEBUG: Data: {'change': -1, 'timespan': ['15:00', '19:00']}
# 2024-12-13 22:32:56, DEBUG: Editing lanes to existing=None change=0 set=None scoped=ScopedPropertySetList(root=[IndivScopedPropertySetItem(category='any', timespan=['06:00', '10:00'], set=None, existing=None, overwrite_conflicts=False, change=-1), IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=None, existing=None, overwrite_conflicts=False, change=-1)]) overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:32:56, DEBUG: Changing lanes by 0
# 2024-12-13 22:32:56, DEBUG: Setting sc_lanes to root=[IndivScopedPropertySetItem(category='any', timespan=['06:00', '10:00'], set=None, existing=None, overwrite_conflicts=False, change=-1), IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=None, existing=None, overwrite_conflicts=False, change=-1)]
# 2024-12-13 22:32:56, DEBUG: prop_dict:
# {'set': 0, 'scoped': [{'set': 1, 'timespan': ['06:00', '10:00']}, {'set': 1, 'timespan': ['15:00', '19:00']}]}
# 2024-12-13 22:32:56, DEBUG: Editing ML_lanes on links [49605, 216760, 232193, 300668, 347381, 385373, 385831, 424003, 461882, 531091, 1750230, 1750231]
# 2024-12-13 22:32:56, DEBUG: Data: {'set': 1, 'timespan': ['06:00', '10:00']}
# 2024-12-13 22:32:56, DEBUG: Data: {'set': 1, 'timespan': ['15:00', '19:00']}
# 2024-12-13 22:32:56, DEBUG: Editing ML_lanes to existing=None change=None set=0 scoped=ScopedPropertySetList(root=[IndivScopedPropertySetItem(category='any', timespan=['06:00', '10:00'], set=1, existing=None, overwrite_conflicts=False, change=None), IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=1, existing=None, overwrite_conflicts=False, change=None)]) overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:32:56, DEBUG: Setting ML_lanes to 0
# 2024-12-13 22:32:56, DEBUG: Setting sc_ML_lanes to root=[IndivScopedPropertySetItem(category='any', timespan=['06:00', '10:00'], set=1, existing=None, overwrite_conflicts=False, change=None), IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=1, existing=None, overwrite_conflicts=False, change=None)]
# 2024-12-13 22:32:56, DEBUG: prop_dict:
# {'set': 'all'}
# 2024-12-13 22:32:56, DEBUG: Editing ML_access on links [49605, 216760, 232193, 300668, 347381, 385373, 385831, 424003, 461882, 531091, 1750230, 1750231]
# 2024-12-13 22:32:56, DEBUG: Editing ML_access to existing=None change=None set='all' scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:32:56, DEBUG: Setting ML_access to all
# 2024-12-13 22:32:56, DEBUG: prop_dict:
# {'set': 'all'}
# 2024-12-13 22:32:56, DEBUG: Editing ML_egress on links [49605, 216760, 232193, 300668, 347381, 385373, 385831, 424003, 461882, 531091, 1750230, 1750231]
# 2024-12-13 22:32:56, DEBUG: Editing ML_egress to existing=None change=None set='all' scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:32:56, DEBUG: Setting ML_egress to all
# 2024-12-13 22:32:56, DEBUG: prop_dict:
# {'set': 113}
# 2024-12-13 22:32:56, DEBUG: Editing MNPASS_CODE on links [49605, 216760, 232193, 300668, 347381, 385373, 385831, 424003, 461882, 531091, 1750230, 1750231]
# 2024-12-13 22:32:56, DEBUG: Editing MNPASS_CODE to existing=None change=None set=113 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:32:56, DEBUG: Setting MNPASS_CODE to 113
# 2024-12-13 22:32:56, DEBUG: prop_dict:
# {'set': 13}
# 2024-12-13 22:32:56, DEBUG: Editing ML_MNPASS_CODE on links [49605, 216760, 232193, 300668, 347381, 385373, 385831, 424003, 461882, 531091, 1750230, 1750231]
# 2024-12-13 22:32:56, DEBUG: Editing ML_MNPASS_CODE to existing=None change=None set=13 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:32:56, DEBUG: Setting ML_MNPASS_CODE to 13
# 2024-12-13 22:32:56, WARNING: Access point not set in project card for a new managed lane.
# Setting ML_access_point to True for selected links.
# 2024-12-13 22:32:56, WARNING: Egress point not set in project card for a new managed lane.
# Setting ML_egress_point to True for selected links.
# 2024-12-13 22:33:13, INFO: Applying 494 eb segment 2 managed lane from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_MnPASS2050_v1\494_EB_Seg2_MnPASS.yml
# 2024-12-13 22:33:13, DEBUG: types: ['roadway_property_change']
# 2024-12-13 22:33:13, DEBUG: type: roadway_property_change
# 2024-12-13 22:33:13, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:33:13, DEBUG: Getting selection from key: 197b04ec8a21987b4126f98003cf4a5a26113ed8
# 2024-12-13 22:33:13, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [130932, 524539, 373924, 432573, 51420, 339580, 437483, 1750228, 1750229, 102609, 318778, 49057, 6659], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:33:16, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:33:16, DEBUG: Applying roadway property change project.
# 2024-12-13 22:33:20, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:33:21, INFO: Final selected links: 13
# 2024-12-13 22:33:27, DEBUG: prop_dict:
# {'change': 0, 'scoped': [{'change': -1, 'timespan': ['06:00', '10:00']}, {'change': -1, 'timespan': ['15:00', '19:00']}]}
# 2024-12-13 22:33:27, DEBUG: Editing lanes on links [6659, 49057, 51420, 102609, 130932, 318778, 339580, 373924, 432573, 437483, 524539, 1750228, 1750229]
# 2024-12-13 22:33:27, DEBUG: Data: {'change': -1, 'timespan': ['06:00', '10:00']}
# 2024-12-13 22:33:27, DEBUG: Data: {'change': -1, 'timespan': ['15:00', '19:00']}
# 2024-12-13 22:33:27, DEBUG: Editing lanes to existing=None change=0 set=None scoped=ScopedPropertySetList(root=[IndivScopedPropertySetItem(category='any', timespan=['06:00', '10:00'], set=None, existing=None, overwrite_conflicts=False, change=-1), IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=None, existing=None, overwrite_conflicts=False, change=-1)]) overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:27, DEBUG: Changing lanes by 0
# 2024-12-13 22:33:27, DEBUG: Setting sc_lanes to root=[IndivScopedPropertySetItem(category='any', timespan=['06:00', '10:00'], set=None, existing=None, overwrite_conflicts=False, change=-1), IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=None, existing=None, overwrite_conflicts=False, change=-1)]
# 2024-12-13 22:33:27, DEBUG: prop_dict:
# {'set': 0, 'scoped': [{'set': 1, 'timespan': ['06:00', '10:00']}, {'set': 1, 'timespan': ['15:00', '19:00']}]}
# 2024-12-13 22:33:27, DEBUG: Editing ML_lanes on links [6659, 49057, 51420, 102609, 130932, 318778, 339580, 373924, 432573, 437483, 524539, 1750228, 1750229]
# 2024-12-13 22:33:27, DEBUG: Data: {'set': 1, 'timespan': ['06:00', '10:00']}
# 2024-12-13 22:33:27, DEBUG: Data: {'set': 1, 'timespan': ['15:00', '19:00']}
# 2024-12-13 22:33:27, DEBUG: Editing ML_lanes to existing=None change=None set=0 scoped=ScopedPropertySetList(root=[IndivScopedPropertySetItem(category='any', timespan=['06:00', '10:00'], set=1, existing=None, overwrite_conflicts=False, change=None), IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=1, existing=None, overwrite_conflicts=False, change=None)]) overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:27, DEBUG: Setting ML_lanes to 0
# 2024-12-13 22:33:27, DEBUG: Setting sc_ML_lanes to root=[IndivScopedPropertySetItem(category='any', timespan=['06:00', '10:00'], set=1, existing=None, overwrite_conflicts=False, change=None), IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=1, existing=None, overwrite_conflicts=False, change=None)]
# 2024-12-13 22:33:27, DEBUG: prop_dict:
# {'set': 'all'}
# 2024-12-13 22:33:27, DEBUG: Editing ML_access on links [6659, 49057, 51420, 102609, 130932, 318778, 339580, 373924, 432573, 437483, 524539, 1750228, 1750229]
# 2024-12-13 22:33:27, DEBUG: Editing ML_access to existing=None change=None set='all' scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:27, DEBUG: Setting ML_access to all
# 2024-12-13 22:33:27, DEBUG: prop_dict:
# {'set': 'all'}
# 2024-12-13 22:33:27, DEBUG: Editing ML_egress on links [6659, 49057, 51420, 102609, 130932, 318778, 339580, 373924, 432573, 437483, 524539, 1750228, 1750229]
# 2024-12-13 22:33:27, DEBUG: Editing ML_egress to existing=None change=None set='all' scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:27, DEBUG: Setting ML_egress to all
# 2024-12-13 22:33:27, DEBUG: prop_dict:
# {'set': 114}
# 2024-12-13 22:33:27, DEBUG: Editing MNPASS_CODE on links [6659, 49057, 51420, 102609, 130932, 318778, 339580, 373924, 432573, 437483, 524539, 1750228, 1750229]
# 2024-12-13 22:33:27, DEBUG: Editing MNPASS_CODE to existing=None change=None set=114 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:27, DEBUG: Setting MNPASS_CODE to 114
# 2024-12-13 22:33:27, DEBUG: prop_dict:
# {'set': 14}
# 2024-12-13 22:33:27, DEBUG: Editing ML_MNPASS_CODE on links [6659, 49057, 51420, 102609, 130932, 318778, 339580, 373924, 432573, 437483, 524539, 1750228, 1750229]
# 2024-12-13 22:33:27, DEBUG: Editing ML_MNPASS_CODE to existing=None change=None set=14 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:27, DEBUG: Setting ML_MNPASS_CODE to 14
# 2024-12-13 22:33:27, WARNING: Access point not set in project card for a new managed lane.
# Setting ML_access_point to True for selected links.
# 2024-12-13 22:33:27, WARNING: Egress point not set in project card for a new managed lane.
# Setting ML_egress_point to True for selected links.
# 2024-12-13 22:33:44, INFO: Applying 35w north sb s2 managed lane from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_MnPASS2050_v1\35WNorth_SB_S2_MnPASS.yml
# 2024-12-13 22:33:44, DEBUG: types: ['roadway_property_change']
# 2024-12-13 22:33:44, DEBUG: type: roadway_property_change
# 2024-12-13 22:33:44, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:33:44, DEBUG: Getting selection from key: 97fd404bf2d81a4736847b7df09b0e7781f6fcb6
# 2024-12-13 22:33:44, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [80193, 172146, 241807, 258097, 314865, 322596, 445208, 489614, 12478, 62008, 72590, 198766, 232954, 264091, 265777, 311933, 359994], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:33:47, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:33:47, DEBUG: Applying roadway property change project.
# 2024-12-13 22:33:51, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:33:51, INFO: Final selected links: 17
# 2024-12-13 22:33:57, DEBUG: prop_dict:
# {'change': 0, 'scoped': [{'change': -1, 'timespan': ['6:00', '10:00']}]}
# 2024-12-13 22:33:57, DEBUG: Editing lanes on links [12478, 62008, 72590, 80193, 172146, 198766, 232954, 241807, 258097, 264091, 265777, 311933, 314865, 322596, 359994, 445208, 489614]
# 2024-12-13 22:33:57, DEBUG: Data: {'change': -1, 'timespan': ['6:00', '10:00']}
# 2024-12-13 22:33:57, DEBUG: Editing lanes to existing=None change=0 set=None scoped=ScopedPropertySetList(root=[IndivScopedPropertySetItem(category='any', timespan=['6:00', '10:00'], set=None, existing=None, overwrite_conflicts=False, change=-1)]) overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:57, DEBUG: Changing lanes by 0
# 2024-12-13 22:33:57, DEBUG: Setting sc_lanes to root=[IndivScopedPropertySetItem(category='any', timespan=['6:00', '10:00'], set=None, existing=None, overwrite_conflicts=False, change=-1)]
# 2024-12-13 22:33:57, DEBUG: prop_dict:
# {'set': 0, 'scoped': [{'set': 1, 'timespan': ['6:00', '10:00']}]}
# 2024-12-13 22:33:57, DEBUG: Editing ML_lanes on links [12478, 62008, 72590, 80193, 172146, 198766, 232954, 241807, 258097, 264091, 265777, 311933, 314865, 322596, 359994, 445208, 489614]
# 2024-12-13 22:33:57, DEBUG: Data: {'set': 1, 'timespan': ['6:00', '10:00']}
# 2024-12-13 22:33:57, DEBUG: Editing ML_lanes to existing=None change=None set=0 scoped=ScopedPropertySetList(root=[IndivScopedPropertySetItem(category='any', timespan=['6:00', '10:00'], set=1, existing=None, overwrite_conflicts=False, change=None)]) overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:57, DEBUG: Setting ML_lanes to 0
# 2024-12-13 22:33:57, DEBUG: Setting sc_ML_lanes to root=[IndivScopedPropertySetItem(category='any', timespan=['6:00', '10:00'], set=1, existing=None, overwrite_conflicts=False, change=None)]
# 2024-12-13 22:33:57, DEBUG: prop_dict:
# {'set': 'all'}
# 2024-12-13 22:33:57, DEBUG: Editing ML_access on links [12478, 62008, 72590, 80193, 172146, 198766, 232954, 241807, 258097, 264091, 265777, 311933, 314865, 322596, 359994, 445208, 489614]
# 2024-12-13 22:33:57, DEBUG: Editing ML_access to existing=None change=None set='all' scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:57, DEBUG: Setting ML_access to all
# 2024-12-13 22:33:57, DEBUG: prop_dict:
# {'set': 'all'}
# 2024-12-13 22:33:57, DEBUG: Editing ML_egress on links [12478, 62008, 72590, 80193, 172146, 198766, 232954, 241807, 258097, 264091, 265777, 311933, 314865, 322596, 359994, 445208, 489614]
# 2024-12-13 22:33:57, DEBUG: Editing ML_egress to existing=None change=None set='all' scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:57, DEBUG: Setting ML_egress to all
# 2024-12-13 22:33:57, DEBUG: prop_dict:
# {'set': 117}
# 2024-12-13 22:33:57, DEBUG: Editing MNPASS_CODE on links [12478, 62008, 72590, 80193, 172146, 198766, 232954, 241807, 258097, 264091, 265777, 311933, 314865, 322596, 359994, 445208, 489614]
# 2024-12-13 22:33:57, DEBUG: Editing MNPASS_CODE to existing=None change=None set=117 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:57, DEBUG: Setting MNPASS_CODE to 117
# 2024-12-13 22:33:57, DEBUG: prop_dict:
# {'set': 17}
# 2024-12-13 22:33:57, DEBUG: Editing ML_MNPASS_CODE on links [12478, 62008, 72590, 80193, 172146, 198766, 232954, 241807, 258097, 264091, 265777, 311933, 314865, 322596, 359994, 445208, 489614]
# 2024-12-13 22:33:57, DEBUG: Editing ML_MNPASS_CODE to existing=None change=None set=17 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:33:57, DEBUG: Setting ML_MNPASS_CODE to 17
# 2024-12-13 22:33:57, WARNING: Access point not set in project card for a new managed lane.
# Setting ML_access_point to True for selected links.
# 2024-12-13 22:33:57, WARNING: Egress point not set in project card for a new managed lane.
# Setting ML_egress_point to True for selected links.
# 2024-12-13 22:34:14, INFO: Applying 35w north nb s2 managed lane from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_MnPASS2050_v1\35WNorth_NB_S2_MnPASS.yml
# 2024-12-13 22:34:14, DEBUG: types: ['roadway_property_change']
# 2024-12-13 22:34:14, DEBUG: type: roadway_property_change
# 2024-12-13 22:34:14, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:34:15, DEBUG: Getting selection from key: 92b99378d94b6990c139514f006ca9000428df5a
# 2024-12-13 22:34:15, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [165786, 188749, 198227, 343727, 441614, 446277, 464900, 544208, 27252, 129583, 227145, 259656, 487005], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:34:18, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:34:18, DEBUG: Applying roadway property change project.
# 2024-12-13 22:34:22, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:34:22, INFO: Final selected links: 13
# 2024-12-13 22:34:29, DEBUG: prop_dict:
# {'change': 0, 'scoped': [{'change': -1, 'timespan': ['15:00', '19:00']}]}
# 2024-12-13 22:34:29, DEBUG: Editing lanes on links [27252, 129583, 165786, 188749, 198227, 227145, 259656, 343727, 441614, 446277, 464900, 487005, 544208]
# 2024-12-13 22:34:29, DEBUG: Data: {'change': -1, 'timespan': ['15:00', '19:00']}
# 2024-12-13 22:34:29, DEBUG: Editing lanes to existing=None change=0 set=None scoped=ScopedPropertySetList(root=[IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=None, existing=None, overwrite_conflicts=False, change=-1)]) overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:34:29, DEBUG: Changing lanes by 0
# 2024-12-13 22:34:29, DEBUG: Setting sc_lanes to root=[IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=None, existing=None, overwrite_conflicts=False, change=-1)]
# 2024-12-13 22:34:29, DEBUG: prop_dict:
# {'set': 0, 'scoped': [{'set': 1, 'timespan': ['15:00', '19:00']}]}
# 2024-12-13 22:34:29, DEBUG: Editing ML_lanes on links [27252, 129583, 165786, 188749, 198227, 227145, 259656, 343727, 441614, 446277, 464900, 487005, 544208]
# 2024-12-13 22:34:29, DEBUG: Data: {'set': 1, 'timespan': ['15:00', '19:00']}
# 2024-12-13 22:34:29, DEBUG: Editing ML_lanes to existing=None change=None set=0 scoped=ScopedPropertySetList(root=[IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=1, existing=None, overwrite_conflicts=False, change=None)]) overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:34:29, DEBUG: Setting ML_lanes to 0
# 2024-12-13 22:34:29, DEBUG: Setting sc_ML_lanes to root=[IndivScopedPropertySetItem(category='any', timespan=['15:00', '19:00'], set=1, existing=None, overwrite_conflicts=False, change=None)]
# 2024-12-13 22:34:29, DEBUG: prop_dict:
# {'set': 'all'}
# 2024-12-13 22:34:29, DEBUG: Editing ML_access on links [27252, 129583, 165786, 188749, 198227, 227145, 259656, 343727, 441614, 446277, 464900, 487005, 544208]
# 2024-12-13 22:34:29, DEBUG: Editing ML_access to existing=None change=None set='all' scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:34:29, DEBUG: Setting ML_access to all
# 2024-12-13 22:34:29, DEBUG: prop_dict:
# {'set': 'all'}
# 2024-12-13 22:34:29, DEBUG: Editing ML_egress on links [27252, 129583, 165786, 188749, 198227, 227145, 259656, 343727, 441614, 446277, 464900, 487005, 544208]
# 2024-12-13 22:34:29, DEBUG: Editing ML_egress to existing=None change=None set='all' scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:34:29, DEBUG: Setting ML_egress to all
# 2024-12-13 22:34:29, DEBUG: prop_dict:
# {'set': 118}
# 2024-12-13 22:34:29, DEBUG: Editing MNPASS_CODE on links [27252, 129583, 165786, 188749, 198227, 227145, 259656, 343727, 441614, 446277, 464900, 487005, 544208]
# 2024-12-13 22:34:29, DEBUG: Editing MNPASS_CODE to existing=None change=None set=118 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:34:29, DEBUG: Setting MNPASS_CODE to 118
# 2024-12-13 22:34:29, DEBUG: prop_dict:
# {'set': 18}
# 2024-12-13 22:34:29, DEBUG: Editing ML_MNPASS_CODE on links [27252, 129583, 165786, 188749, 198227, 227145, 259656, 343727, 441614, 446277, 464900, 487005, 544208]
# 2024-12-13 22:34:29, DEBUG: Editing ML_MNPASS_CODE to existing=None change=None set=18 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:34:29, DEBUG: Setting ML_MNPASS_CODE to 18
# 2024-12-13 22:34:29, WARNING: Access point not set in project card for a new managed lane.
# Setting ML_access_point to True for selected links.
# 2024-12-13 22:34:29, WARNING: Egress point not set in project card for a new managed lane.
# Setting ML_egress_point to True for selected links.
# 2024-12-13 22:34:47, INFO: Applying wbroadwayave85th93rd2to4lanes from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_TPP2050_v1\wbroadwayave85th93rd2to4lanes.yml
# 2024-12-13 22:34:47, DEBUG: types: ['roadway_property_change']
# 2024-12-13 22:34:47, DEBUG: type: roadway_property_change
# 2024-12-13 22:34:47, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:34:47, DEBUG: Getting selection from key: 3f537119967e1086146e578b594e973ad62d0324
# 2024-12-13 22:34:47, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [122821, 644190, 340302, 886151, 822233, 333083, 45274, 841715, 34421, 874932, 921538, 41700, 281507, 932829], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:34:51, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:34:51, DEBUG: Applying roadway property change project.
# 2024-12-13 22:34:54, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:34:55, INFO: Final selected links: 14
# 2024-12-13 22:35:01, DEBUG: prop_dict:
# {'existing': 1.0, 'set': 2.0}
# 2024-12-13 22:35:01, DEBUG: Editing lanes on links [34421, 41700, 45274, 122821, 281507, 333083, 340302, 644190, 822233, 841715, 874932, 886151, 921538, 932829]
# 2024-12-13 22:35:01, DEBUG: Editing lanes to existing=1.0 change=None set=2.0 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:35:01, DEBUG: Setting lanes to 2.0
# 2024-12-13 22:35:18, INFO: Applying riverview network edits from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_TPP2050_v1\riverview2050network.yml
# 2024-12-13 22:35:18, DEBUG: types: ['roadway_deletion', 'roadway_addition', 'roadway_property_change']
# 2024-12-13 22:35:18, DEBUG: type: multiple
# 2024-12-13 22:35:18, DEBUG: - applying subproject: roadway_deletion
# 2024-12-13 22:35:18, DEBUG: Deleting Roadway Features:
# links=SelectLinksDict(all=False, name=None, ref=None, osm_link_id=None, model_link_id=[8629], modes=['any'], ignore_missing=True) nodes=None clean_shapes=False clean_nodes=False
# 2024-12-13 22:35:18, DEBUG: Getting selection from key: 8b2fc3d1471f63611abdc4c9e62e6db4a86f5693
# 2024-12-13 22:35:18, DEBUG: Creating selection from selection dictionary:
#  {'links': {'all': False, 'model_link_id': [8629], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:35:21, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:35:25, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:35:25, INFO: Final selected links: 1
# 2024-12-13 22:35:25, DEBUG:
#                    model_link_id       A       B name  rail_only  bus_only  \
# model_link_id_idx
# 8629                        8629  198492  198322           False     False
#
#                    drive_access  bike_access  walk_access  distance  ... bike  \
# model_link_id_idx                                                    ...
# 8629                       True        False        False  0.057863  ...    0
#
#                   walk  MNPASS_CODE MNPASS_PAY  ML_egress  ML_MNPASS_CODE  \
# model_link_id_idx
# 8629                 0          0.0        0.0       None             NaN
#
#                   sc_lanes sc_ML_lanes  \
# model_link_id_idx
# 8629                  None        None
#
#                                                             geometry  \
# model_link_id_idx
# 8629               LINESTRING (-93.18504 44.89153, -93.18413 44.8...
#
#                    ML_geometry
# model_link_id_idx
# 8629                      None
#
# [1 rows x 71 columns]
# 2024-12-13 22:35:29, DEBUG: Deleting links with ids:
# [8629]
# 2024-12-13 22:35:35, DEBUG: - applying subproject: roadway_addition
# 2024-12-13 22:35:35, DEBUG: Adding New Roadway Features:
# -Links:
# [{'A': 417272, 'B': 500100, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750343, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500100, 'B': 417258, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750344, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500100, 'B': 500101, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750345, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500101, 'B': 500100, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750346, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500101, 'B': 500102, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750347, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500102, 'B': 500101, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750348, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500102, 'B': 500103, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750349, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500103, 'B': 500102, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750350, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500103, 'B': 500104, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750351, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500104, 'B': 500103, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750352, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 4, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 500104, 'B': 500105, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750353, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_t ...
# -Nodes:
# [{'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 500100, 'osm_node_id': '', 'X': -93.19531520214524, 'Y': 44.894231157390706}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 500101, 'osm_node_id': '', 'X': -93.19181637024947, 'Y': 44.894483598702955}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 500102, 'osm_node_id': '', 'X': -93.18821091770506, 'Y': 44.893066867058536}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 500103, 'osm_node_id': '', 'X': -93.18488511302091, 'Y': 44.89176552317802}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 500104, 'osm_node_id': '', 'X': -93.17868195143444, 'Y': 44.89752668254832}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 500105, 'osm_node_id': '', 'X': -93.1703283125026, 'Y': 44.901829071817794}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 500106, 'osm_node_id': '', 'X': -93.12537666565822, 'Y': 44.928593966244996}]
# 2024-12-13 22:35:35, DEBUG: Turning node data into official nodes_df
# 2024-12-13 22:35:35, DEBUG: Created node geometries from X and Y in 0.02.
# 2024-12-13 22:35:36, DEBUG: Creating 26 links.
# 2024-12-13 22:35:36, DEBUG: 26 new links.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 22:35:55, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:35:55, DEBUG: Getting selection from key: 2dd0d82d19b77cdf8d355be1bb2616456b117d98
# 2024-12-13 22:35:55, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [916079, 145463, 875383, 19242, 1024526, 598444, 385792, 331535, 38787, 1053870, 256222, 960468, 625416, 399546, 971241, 438979, 839492, 428272, 1053790, 985128, 179283, 8203, 627378, 521795, 346446, 867183, 670636, 313889, 934774, 104099, 760056, 878336, 91330, 70065, 781073, 611782, 160523, 462239, 610965, 985959, 454230, 32230, 490303, 902439, 314830, 801891, 160953, 453150, 630684, 875255, 96833, 979826, 490068, 51002, 907837, 353750, 313431, 281670, 945434, 829305, 249512, 781913, 597129, 536503, 878810, 145554, 929891, 544675, 645813, 678232, 367699, 455751, 562845, 1021112, 410945, 404402, 488333, 453824, 681837, 548157, 849226, 70985, 973597, 508710, 829562, 567369, 175881, 971532, 548179, 474919, 879577, 450203, 16412, 825022, 212738, 726494, 587194, 389817, 749642, 811588, 431011, 344132, 525751, 964062, 575326, 421413, 804055, 463375, 336280, 185393, 992651, 81671, 410546, 609277, 763248, 115043, 439919, 197640, 507431, 714524, 409732, 515487, 1038284, 650199, 974369, 232279, 445983, 32240, 471820, 716539, 465358, 789824, 471211, 907320, 448576, 898203, 359211, 941332, 539, 856409, 143352, 748862, 327064, 989653, 237538, 264092, 947100, 93622, 925294, 509156, 610827, 104162, 410458, 611648, 324394, 431992], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:35:59, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:35:59, DEBUG: Applying roadway property change project.
# 2024-12-13 22:36:03, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:36:03, INFO: Final selected links: 156
# 2024-12-13 22:36:10, DEBUG: prop_dict:
# {'existing': 2.0, 'set': 1.0}
# 2024-12-13 22:36:10, DEBUG: Editing lanes on links [539, 8203, 16412, 19242, 32230, 32240, 38787, 51002, 70065, 70985, 81671, 91330, 93622, 96833, 104099, 104162, 115043, 143352, 145463, 145554, 160523, 160953, 175881, 179283, 185393, 197640, 212738, 232279, 237538, 249512, 256222, 264092, 281670, 313431, 313889, 314830, 324394, 327064, 331535, 336280, 344132, 346446, 353750, 359211, 367699, 385792, 389817, 399546, 404402, 409732, 410458, 410546, 410945, 421413, 428272, 431011, 431992, 438979, 439919, 445983, 448576, 450203, 453150, 453824, 454230, 455751, 462239, 463375, 465358, 471211, 471820, 474919, 488333, 490068, 490303, 507431, 508710, 509156, 515487, 521795, 525751, 536503, 544675, 548157, 548179, 562845, 567369, 575326, 587194, 597129, 598444, 609277, 610827, 610965, 611648, 611782, 625416, 627378, 630684, 645813, 650199, 670636, 678232, 681837, 714524, 716539, 726494, 748862, 749642, 760056, 763248, 781073, 781913, 789824, 801891, 804055, 811588, 825022, 829305, 829562, 839492, 849226, 856409, 867183, 875255, 875383, 878336, 878810, 879577, 898203, 902439, 907320, 907837, 916079, 925294, 929891, 934774, 941332, 945434, 947100, 960468, 964062, 971241, 971532, 973597, 974369, 979826, 985128, 985959, 989653, 992651, 1021112, 1024526, 1038284, 1053790, 1053870]
# 2024-12-13 22:36:10, DEBUG: Editing lanes to existing=2.0 change=None set=1.0 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:36:10, DEBUG: Setting lanes to 1.0
# 2024-12-13 22:36:27, INFO: Applying mn65bunkerlakerdintchng from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_TPP2050_v1\mn65bunkerlakerdintchng.yml
# 2024-12-13 22:36:27, DEBUG: types: ['roadway_deletion', 'roadway_addition', 'roadway_property_change']
# 2024-12-13 22:36:27, DEBUG: type: multiple
# 2024-12-13 22:36:27, DEBUG: - applying subproject: roadway_deletion
# 2024-12-13 22:36:27, DEBUG: Deleting Roadway Features:
# links=SelectLinksDict(all=False, name=None, ref=None, osm_link_id=None, model_link_id=[68245, 320823, 542588, 151605, 31146, 397573, 115266, 129962], modes=['any'], ignore_missing=True) nodes=None clean_shapes=False clean_nodes=False
# 2024-12-13 22:36:27, DEBUG: Getting selection from key: f990343e1da68b9e0b4ac85e8d9a24661d394351
# 2024-12-13 22:36:27, DEBUG: Creating selection from selection dictionary:
#  {'links': {'all': False, 'model_link_id': [68245, 320823, 542588, 151605, 31146, 397573, 115266, 129962], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:36:32, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:36:36, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:36:36, INFO: Final selected links: 8
# 2024-12-13 22:36:41, DEBUG: Deleting links with ids:
# [31146, 68245, 115266, 129962, 151605, 320823, 397573, 542588]
# 2024-12-13 22:36:48, DEBUG: - applying subproject: roadway_addition
# 2024-12-13 22:36:48, DEBUG: Adding New Roadway Features:
# -Links:
# [{'A': 387856, 'B': 900062, 'name': 'Bunker Lake Boulevard Northeast', 'roadway': 'tertiary', 'drive_access': 1, 'walk_access': 1, 'bike_access': 1, 'county': 1, 'model_link_id': 1900146, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 5, 'roadway_class': 40, 'area_type': 1, 'bike': 3, 'walk': 3, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 2}, {'A': 900061, 'B': 37589, 'name': 'new_link - TODO NAME ME!', 'roadway': 'trunk', 'drive_access': 1, 'walk_access': 0, 'bike_access': 0, 'county': 1, 'model_link_id': 1900147, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 15, 'roadway_class': 20, 'area_type': 1, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 2}, {'A': 387874, 'B': 900063, 'name': 'Bunker Lake Boulevard Northeast', 'roadway': 'tertiary', 'drive_access': 1, 'walk_access': 1, 'bike_access': 1, 'county': 1, 'model_link_id': 1900148, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 5, 'roadway_class': 40, 'area_type': 1, 'bike': 3, 'walk': 3, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 2}, {'A': 900063, 'B': 387871, 'name': 'Bunker Lake Boulevard Northeast', 'roadway': 'tertiary', 'drive_access': 1, 'walk_access': 1, 'bike_access': 1, 'county': 1, 'model_link_id': 1900149, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 5, 'roadway_class': 40, 'area_type': 1, 'bike': 3, 'walk': 3, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 2}, {'A': 900064, 'B': 55371, 'name': 'new_link - TODO NAME ME!', 'roadway': 'trunk', 'drive_access': 1, 'walk_access': 0, 'bike_access': 0, 'county': 1, 'model_link_id': 1900150, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 15, 'roadway_class': 20, 'area_type': 1, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 2}, {'A': 900062, 'B': 387873, 'name': 'Bunker Lake Boulevard Northeast', 'roadway': 'tertiary', 'drive_access': 1, 'walk_access': 1, 'bike_access': 1, 'county': 1, 'model_link_id': 1900151, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 5, 'roadway_class': 40, 'area_type': 1, 'bike': 3, 'walk': 3, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 2}, {'A': 387867, 'B': 900061, 'name': 'new_link - TODO NAME ME!', 'roadway': 'trunk', 'drive_access': 1, 'walk_access': 0, 'bike_access': 0, 'county': 1, 'model_link_id': 1900152, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 15, 'roadway_class': 20, 'area_type': 1, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 2}, {'A': 387869, 'B': 900064, 'name': 'new_link - TODO NAME ME!', 'roadway': 'trunk', 'drive_access': 1, 'walk_access': 0, 'bike_access': 0, 'county': 1, 'model_link_id': 1900153, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 15, 'roadway_class': 20, 'area_type': 1, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 2}, {'A': 900062, 'B': 900061, 'name': 'new_link - TODO NAME ME!', 'roadway': 'trunk_link', 'drive_access': 1, 'walk_access': 0, 'bike_access': 0, 'county': 1, 'model_link_id': 1900154, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 4, 'roadway_class': 20, 'area_type': 1, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 900063, 'B': 900064, 'name': 'new_link - TODO NAME ME!', 'roadway': 'trunk_link', 'drive_access': 1, 'walk_access': 0, 'bike_access': 0, 'county': 1, 'model_link_id': 1900155, 'rail_only': 0, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 4, 'roadway_class': 20, 'area_type': 1, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}]
# -Nodes:
# [{'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 900061, 'osm_node_id': '', 'X': -93.23439444523368, 'Y': 45.219437560885105}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 900062, 'osm_node_id': '', 'X': -93.23377162789517, 'Y': 45.2189476505577}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 900063, 'osm_node_id': '', 'X': -93.23535232498637, 'Y': 45.21881103994837}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 900064, 'osm_node_id': '', 'X': -93.2347529488788, 'Y': 45.21814855382746}]
# 2024-12-13 22:36:48, DEBUG: Turning node data into official nodes_df
# 2024-12-13 22:36:48, DEBUG: Created node geometries from X and Y in 0.0.
# 2024-12-13 22:36:48, DEBUG: nodes_df:
#    model_node_id                    geometry          X          Y
# 0         900061  POINT (-93.23439 45.21944) -93.234394  45.219438
# 1         900062  POINT (-93.23377 45.21895) -93.233772  45.218948
# 2         900063  POINT (-93.23535 45.21881) -93.235352  45.218811
# 3         900064  POINT (-93.23475 45.21815) -93.234753  45.218149
# 2024-12-13 22:36:49, DEBUG: Creating 10 links.
# 2024-12-13 22:36:49, DEBUG: 10 new links.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 22:37:09, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:37:09, DEBUG: Getting selection from key: 897e6a788768b87f8a304c3de0f49e30971c0ed2
# 2024-12-13 22:37:09, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [128366, 144881], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:37:12, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:37:12, DEBUG: Applying roadway property change project.
# 2024-12-13 22:37:16, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:37:16, INFO: Final selected links: 2
# 2024-12-13 22:37:16, DEBUG:
#                    model_link_id       A       B name  rail_only  bus_only  \
# model_link_id_idx
# 128366                    128366  387867  387866           False     False
# 144881                    144881  387869  387868           False     False
#
#                    drive_access  bike_access  walk_access  distance  ... bike  \
# model_link_id_idx                                                    ...
# 128366                     True        False        False  0.052659  ...    0
# 144881                     True        False        False  0.042804  ...    0
#
#                   walk  MNPASS_CODE MNPASS_PAY  ML_egress  ML_MNPASS_CODE  \
# model_link_id_idx
# 128366               0          0.0        0.0       None             NaN
# 144881               0          0.0        0.0       None             NaN
#
#                   sc_lanes sc_ML_lanes  \
# model_link_id_idx
# 128366                None        None
# 144881                None        None
#
#                                                             geometry  \
# model_link_id_idx
# 128366             LINESTRING (-93.23436 45.21817, -93.23377 45.2...
# 144881             LINESTRING (-93.23479 45.21943, -93.23535 45.2...
#
#                    ML_geometry
# model_link_id_idx
# 128366                    None
# 144881                    None
#
# [2 rows x 71 columns]
# 2024-12-13 22:37:23, DEBUG: prop_dict:
# {'set': 4.0}
# 2024-12-13 22:37:23, DEBUG: Editing assign_group on links [128366, 144881]
# 2024-12-13 22:37:23, DEBUG: Editing assign_group to existing=None change=None set=4.0 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:37:23, DEBUG: Setting assign_group to 4.0
# 2024-12-13 22:37:39, INFO: Applying mn6585thst93stintchngs from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_TPP2050_v1\mn6585thst93stintchngs.yml
# 2024-12-13 22:37:39, DEBUG: types: ['roadway_addition', 'transit_routing_change', 'transit_routing_change', 'transit_routing_change', 'transit_routing_change', 'roadway_deletion']
# 2024-12-13 22:37:39, DEBUG: type: multiple
# 2024-12-13 22:37:39, DEBUG: - applying subproject: roadway_addition
# 2024-12-13 22:37:40, DEBUG: Adding New Roadway Features:
# -Links:
# ...
# -Nodes:
# [{'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 550550, 'osm_node_id': '', 'X': -93.07116835803261, 'Y': 44.95402029585806}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 550551, 'osm_node_id': '', 'X': -93.05602112319775, 'Y': 44.952163904583855}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 550552, 'osm_node_id': '', 'X': -93.04320609722217, 'Y': 44.9535337140854}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 550553, 'osm_node_id': '', 'X': -93.01964959543203, 'Y': 44.95187291184173}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 550554, 'osm_node_id': '', 'X': -93.01198453005092, 'Y': 44.95134594036756}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 550555, 'osm_node_id': '', 'X': -92.99408092203896, 'Y': 44.94947799047776}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 550556, 'osm_node_id': '', 'X': -92.97308923560513, 'Y': 44.948906322006174}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 550557, 'osm_node_id': '', 'X': -92.95173599658915, 'Y': 44.950301954292534}]
# 2024-12-13 22:55:52, DEBUG: Turning node data into official nodes_df
# 2024-12-13 22:55:52, DEBUG: Created node geometries from X and Y in 0.02.
# 2024-12-13 22:55:53, DEBUG: Creating 20 links.
# 2024-12-13 22:55:53, DEBUG: 20 new links.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 22:56:12, INFO: Applying dakota_cr46 from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_TPP2050_v1\dakota_cr46.yml
# 2024-12-13 22:56:12, DEBUG: types: ['roadway_property_change']
# 2024-12-13 22:56:12, DEBUG: type: roadway_property_change
# 2024-12-13 22:56:12, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:56:12, DEBUG: Getting selection from key: 76dfbc6fafdcd20d7934a72f61c5e54b8e1400cf
# 2024-12-13 22:56:12, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [48745, 188162, 142540, 146348, 336306, 142859, 950020, 555587, 41060, 997120, 127857, 379781, 798371, 425133, 912977, 920457, 478159, 982669, 482963, 981766, 417500, 607880, 77204, 478494, 852219, 870610, 101640, 339992, 487694, 206132, 280440, 402887], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:56:16, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:56:16, DEBUG: Applying roadway property change project.
# 2024-12-13 22:56:20, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:56:20, INFO: Final selected links: 32
# 2024-12-13 22:56:27, DEBUG: prop_dict:
# {'existing': 1.0, 'set': 2.0}
# 2024-12-13 22:56:27, DEBUG: Editing lanes on links [41060, 48745, 77204, 101640, 127857, 142540, 142859, 146348, 188162, 206132, 280440, 336306, 339992, 379781, 402887, 417500, 425133, 478159, 478494, 482963, 487694, 555587, 607880, 798371, 852219, 870610, 912977, 920457, 950020, 981766, 982669, 997120]
# 2024-12-13 22:56:27, DEBUG: Editing lanes to existing=1.0 change=None set=2.0 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:56:27, DEBUG: Setting lanes to 2.0
# 2024-12-13 22:56:44, INFO: Applying cr7 from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_TPP2050_v1\cr7.yml
# 2024-12-13 22:56:44, DEBUG: types: ['roadway_property_change']
# 2024-12-13 22:56:44, DEBUG: type: roadway_property_change
# 2024-12-13 22:56:44, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:56:45, DEBUG: Getting selection from key: 032c121e6c05e379fc01528deb65e11b50bd3a20
# 2024-12-13 22:56:45, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [434497, 884687, 506832, 602233, 542063, 734857, 767470, 224466, 928133, 108475, 146784, 657835, 953133, 42263, 44823, 643596, 49827, 633012, 789872, 504510, 8102, 1020506, 960028, 270556, 401129, 860703, 373393, 714593, 698014, 539912, 467331, 707862, 177860, 791434, 24517, 887576, 454004, 589953], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:56:48, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:56:48, DEBUG: Applying roadway property change project.
# 2024-12-13 22:56:52, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:56:52, INFO: Final selected links: 38
# 2024-12-13 22:56:59, DEBUG: prop_dict:
# {'existing': 1.0, 'set': 2.0}
# 2024-12-13 22:56:59, DEBUG: Editing lanes on links [8102, 24517, 42263, 44823, 49827, 108475, 146784, 177860, 224466, 270556, 373393, 401129, 434497, 454004, 467331, 504510, 506832, 539912, 542063, 589953, 602233, 633012, 643596, 657835, 698014, 707862, 714593, 734857, 767470, 789872, 791434, 860703, 884687, 887576, 928133, 953133, 960028, 1020506]
# 2024-12-13 22:56:59, DEBUG: Editing lanes to existing=1.0 change=None set=2.0 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:56:59, DEBUG: Setting lanes to 2.0
# 2024-12-13 22:57:17, INFO: Applying cr12 from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_TPP2050_v1\cr12.yml
# 2024-12-13 22:57:17, DEBUG: types: ['roadway_property_change']
# 2024-12-13 22:57:17, DEBUG: type: roadway_property_change
# 2024-12-13 22:57:17, DEBUG: - applying subproject: roadway_property_change
# 2024-12-13 22:57:17, DEBUG: Getting selection from key: 2425bd2d366dbe4a129351009d0891956a70081a
# 2024-12-13 22:57:17, DEBUG: Creating selection from selection dictionary:
#  {'links': {'model_link_id': [406605, 496022, 82163, 142335, 984115, 529498, 547735, 592726, 998752, 245688, 202075, 821132, 123815, 1021022, 325729, 994452, 296326, 90243, 530749, 94608, 100621, 147577, 67029, 241172], 'modes': ['any'], 'ignore_missing': True}}
# 2024-12-13 22:57:21, DEBUG: Created LinkSelection of type: query
# 2024-12-13 22:57:21, DEBUG: Applying roadway property change project.
# 2024-12-13 22:57:25, DEBUG: Initial link selection type: links.query
# 2024-12-13 22:57:25, INFO: Final selected links: 24
# 2024-12-13 22:57:31, DEBUG: prop_dict:
# {'existing': 1.0, 'set': 2.0}
# 2024-12-13 22:57:31, DEBUG: Editing lanes on links [67029, 82163, 90243, 94608, 100621, 123815, 142335, 147577, 202075, 241172, 245688, 296326, 325729, 406605, 496022, 529498, 530749, 547735, 592726, 821132, 984115, 994452, 998752, 1021022]
# 2024-12-13 22:57:31, DEBUG: Editing lanes to existing=1.0 change=None set=2.0 scoped=None overwrite_scoped=None existing_value_conflict=None
# 2024-12-13 22:57:31, DEBUG: Setting lanes to 2.0
# 2024-12-13 22:57:49, INFO: Applying bluelineext from file:                            Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\project_card\Build_TPP2050_v1\bluelineext.yml
# 2024-12-13 22:57:49, DEBUG: types: ['roadway_addition']
# 2024-12-13 22:57:49, DEBUG: type: roadway_addition
# 2024-12-13 22:57:49, DEBUG: - applying subproject: roadway_addition
# 2024-12-13 22:57:49, DEBUG: Adding New Roadway Features:
# -Links:
# [{'A': 550000, 'B': 554000, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750279, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 554000, 'B': 234766, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750280, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 234766, 'B': 554001, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750281, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 554001, 'B': 225704, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750282, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 225704, 'B': 554002, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750283, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 554002, 'B': 554003, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750284, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 554003, 'B': 554004, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750285, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 554004, 'B': 554005, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750286, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 554005, 'B': 554004, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750287, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 554005, 'B': 31162, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750288, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_type': 5, 'bike': 0, 'walk': 0, 'MNPASS_CODE': 0, 'MNPASS_PAY': 0, 'managed': 0, 'lanes': 1}, {'A': 31162, 'B': 554005, 'name': 'new_link - TODO NAME ME!', 'roadway': 'road', 'drive_access': 0, 'walk_access': 0, 'bike_access': 0, 'county': 4, 'model_link_id': 1750289, 'rail_only': 1, 'bus_only': 0, 'centroidconnect': 0, 'assign_group': 100, 'roadway_class': 100, 'area_typ ...
# -Nodes:
# [{'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554000, 'osm_node_id': '', 'X': -93.28094476488387, 'Y': 44.99105421975515}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554001, 'osm_node_id': '', 'X': -93.28226189785018, 'Y': 45.00020030118667}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554002, 'osm_node_id': '', 'X': -93.29975671339686, 'Y': 44.999964749840785}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554003, 'osm_node_id': '', 'X': -93.30460082133446, 'Y': 45.000655058978275}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554004, 'osm_node_id': '', 'X': -93.3088644838041, 'Y': 45.004305722082925}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554005, 'osm_node_id': '', 'X': -93.31874211413486, 'Y': 45.01344742050688}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554006, 'osm_node_id': '', 'X': -93.35840772601064, 'Y': 45.05417775537174}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554007, 'osm_node_id': '', 'X': -93.36871872133194, 'Y': 45.0701139664015}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554008, 'osm_node_id': '', 'X': -93.3764120914933, 'Y': 45.083462901618084}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554009, 'osm_node_id': '', 'X': -93.37669457713487, 'Y': 45.09429092141407}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554010, 'osm_node_id': '', 'X': -93.3765803130058, 'Y': 45.10906255339735}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554011, 'osm_node_id': '', 'X': -93.37661093093871, 'Y': 45.12443250163226}, {'drive_access': 0.0, 'walk_access': 0.0, 'bike_access': 0.0, 'county': '0', 'rail_only': 0, 'model_node_id': 554012, 'osm_node_id': '', 'X': -93.37766132550733, 'Y': 45.13406024417344}]
# 2024-12-13 22:57:49, DEBUG: Turning node data into official nodes_df
# 2024-12-13 22:57:49, DEBUG: Created node geometries from X and Y in 0.01.
# 2024-12-13 22:57:50, DEBUG: Creating 32 links.
# 2024-12-13 22:57:50, DEBUG: 32 new links.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(

# %%
version_04_scenario.applied_projects
# Out:
# ['add transit priority part b',
#  'add transit priority',
#  'manual changes to assignment group and roadway class',
#  'add walk and bike attributes',
#  'year 2015 add centroid connector at external stations',
#  'wacoutalink',
#  'stillwaterblvd',
#  'section1_columbus',
#  'nicollet2',
#  'marq_second2',
#  'lex_lake_circlepines2',
#  'lexington1',
#  'hodgsonrd2',
#  'hodgsonrd',
#  'fixwalkbike_warner',
#  'dtmpls_4thave',
#  'avts_split',
#  'anokaminorroads',
#  '12th_busramps',
#  'correct year 2018 assignment group and roadway class',
#  'correct year 2018 assignment group',
#  'route2_wash',
#  'nic_split',
#  'msp_deletes',
#  'missing 394 reverse',
#  'network cleanup 1 lanes 7',
#  'network cleanup 1 lanes 6',
#  'network cleanup 2 lanes 5 a',
#  'network cleanup 1 lanes 5',
#  'network cleanup 2 lanes 4 a',
#  'network cleanup 1 lanes 4',
#  'network cleanup 2 lanes 3 a',
#  'network cleanup 1 lanes 3',
#  'network cleanup 2 lanes 2g',
#  'network cleanup 2 lanes 2 a',
#  'network cleanup 1 lanes 2e',
#  'network cleanup 1 lanes 2 d3',
#  'network cleanup 1 lanes 2d part 2',
#  'network cleanup 1 lanes 2d',
#  'network cleanup 1 lanes 2 c3',
#  'network cleanup 1 lanes 2c part 2',
#  'network cleanup 1 lanes 2c',
#  'network cleanup 1 lanes 2b',
#  'network cleanup 1 lanes 2a',
#  'network cleanup 2 lanes 1 a',
#  'network cleanup 1 lanes 1 h',
#  'network cleanup 1 lanes 1 g2',
#  'network cleanup 1 lanes 1 g',
#  'network cleanup 1 lanes 1 f 3',
#  'network cleanup 1 lanes 1 f part 2',
#  'network cleanup 1 lanes 1 f',
#  'network cleanup 1 lanes 1 e3',
#  'network cleanup 1 lanes 1 e part 2',
#  'network cleanup 1 lanes 1 e',
#  'network cleanup 1 lanes 1 d3',
#  'network cleanup 1 lanes 1 d part 2',
#  'network cleanup 1 lanes 1 d',
#  'network cleanup 1 lanes 1 c3',
#  'network cleanup 1 lanes 1 c part 2',
#  'network cleanup 1 lanes 1 c',
#  'network cleanup 1 lanes 1 b3',
#  'network cleanup 1 lanes 1 b part 2',
#  'network cleanup 1 lanes 1 b',
#  'network cleanup 1 lanes 1 a3',
#  'network cleanup 1 lanes 1 a part2',
#  'network cleanup 1 lanes 1 a',
#  'hwy 61 walk bike',
#  'hiawatha 46th cleanup',
#  'glumack_drive1',
#  'correct zero distance',
#  'clean up model crash 1',
#  'burns_split',
#  'u of m transitway add links',
#  'bus routing correction cont2',
#  'bus routing correction cont',
#  'bus routing correction',
#  'network cleanup 1 asgngrp 7',
#  'network cleanup 2 asgngrp 6',
#  'network cleanup 1 asgngrp 6',
#  'network cleanup 2 asgngrp 5',
#  'network cleanup 1 asgngrp 50',
#  'network cleanup 2 asgngrp 4',
#  'network cleanup 1 asgngrp 4',
#  'network cleanup 2 asgngrp 2',
#  'network cleanup 1 asgngrp 2',
#  'network cleanup 2 asgngrp 1',
#  'network cleanup 2 asgngrp 15',
#  'network cleanup 1 asgngrp 15',
#  'network cleanup 1 asgngrp 101',
#  'network cleanup 1 asgngrp 1',
#  'clean up 35w ramps',
#  'ag2cleanup4',
#  'ag2cleanup3',
#  'ag2cleanup2',
#  'ag2cleanup',
#  'v5 base transit network fix',
#  'add mnpass_code',
#  '394 wb managed lane',
#  '394 reverse lane onramp mnpasspay',
#  '394 reverse lanes by time period',
#  '394 eb managed lane',
#  '35w south sb managed lane',
#  '35w south nb managed lane',
#  '35w north sb managed lane',
#  '35w north nb managed lane',
#  '35e sb managed lane',
#  '35e nb managed lane',
#  '494 wb segment 1 managed lane',
#  '494 eb segment 1 managed lane',
#  '394_louisiana_ave_laneadd',
#  'wright_i94',
#  'us212cr51intchg2to4laneexp',
#  'us169scottco59intchg',
#  'us10ramseysunfishintchg',
#  'th8wacokarmelave',
#  'th65sb',
#  'th65nb',
#  'th36_lakeelmo_rev',
#  'th10',
#  'nicportland_494interchange',
#  'mn5caco11mn41',
#  'mn13dakotaavenobuild',
#  'i94i494woodburydr',
#  '494 wb segment 2 managed lane',
#  '494 eb segment 2 managed lane',
#  '35w north sb s2 managed lane',
#  '35w north nb s2 managed lane',
#  'wbroadwayave85th93rd2to4lanes',
#  'riverview network edits',
#  'mn65bunkerlakerdintchng',
#  'mn6585thst93stintchngs',
#  'mn610eastriverrd',
#  'mn5hennepincr4intchng',
#  'mn36mn120intchng',
#  'mn252hwyconvaccessoption',
#  '94 sb s1 managed lane',
#  '94 nb s1 managed lane',
#  'mn13quentinnicolletaveintchngsedit',
#  'hennepincr81basslakerdintchng',
#  'greenlineext',
#  'goldline',
#  'dakota_cr46',
#  'cr7',
#  'cr12',
#  'bluelineext']

# %%
version_04_scenario.road_net.links_df.columns
# Out:
# Index(['model_link_id', 'A', 'B', 'name', 'rail_only', 'bus_only',
#        'drive_access', 'bike_access', 'walk_access', 'distance', 'roadway',
#        'projects', 'managed', 'shape_id', 'lanes', 'price', 'ref', 'access',
#        'ML_projects', 'ML_lanes', 'ML_access', 'ML_access_point',
#        'ML_egress_point', 'osm_link_id', 'locationReferences',
#        'shstReferenceId', 'shstGeometryId', 'fromIntersectionId',
#        'toIntersectionId', 'u', 'v', 'nodeIds', 'wayId', 'roadClass', 'oneWay',
#        'roundabout', 'link', 'oneway', 'lanes_osm', 'highway', 'service',
#        'width', 'maxspeed', 'junction', 'bridge', 'tunnel', 'landuse', 'area',
#        'key', 'forward', 'backReferenceId', 'metadata', 'source', 'county',
#        'length', 'centroidconnect', 'assign_group', 'roadway_class',
#        'trn_priority', 'area_type', 'ramp_flag', 'bike', 'walk', 'MNPASS_CODE',
#        'MNPASS_PAY', 'ML_egress', 'ML_MNPASS_CODE', 'sc_lanes', 'sc_ML_lanes',
#        'geometry', 'ML_geometry'],
#       dtype='object')

# %% [markdown]
# # Save version 04 scenario and standard networks

# %%
version_04_scenario.write(
    os.path.join(net_dir, 'v04', 'standard_networks'),
    name = 'v04',
    roadway_file_format = "geojson",
    transit_file_format = "txt",
    roadway_write = True,
    transit_write = True,
    projects_write = True,
    overwrite = True,
    roadway_convert_complex_link_properties_to_single_field=True
)
# Out:
# 2024-12-13 22:58:23, DEBUG: Writing to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\roadway\v04_link.json.
# 2024-12-13 22:58:54, DEBUG: Writing to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\roadway\v04_node.geojson.
# 2024-12-13 22:59:10, DEBUG: Reading shapes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\roadway\v03_shape.geojson.
# 2024-12-13 22:59:10, DEBUG: Estimated read time: 8 seconds.
# 2024-12-13 22:59:40, DEBUG: Read 556324 shapes from file in 29.54.
# 2024-12-13 22:59:40, DEBUG: Creating 556324 shapes.
# 2024-12-13 22:59:41, INFO: Read 556324 shapes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v03\standard_networks\roadway\v03_shape.geojson in 30.81.
# 2024-12-13 22:59:43, DEBUG: Writing to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\roadway\v04_shape.geojson.
# 2024-12-13 23:00:15, DEBUG: Writing to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_frequencies.txt.
# 2024-12-13 23:00:15, DEBUG: Writing to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_routes.txt.
# 2024-12-13 23:00:15, DEBUG: Writing to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_shapes.txt.
# 2024-12-13 23:00:16, DEBUG: Writing to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_stops.txt.
# 2024-12-13 23:00:17, DEBUG: Writing to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_trips.txt.
# 2024-12-13 23:00:17, DEBUG: Writing to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_stop_times.txt.
# 2024-12-13 23:00:18, INFO: Wrote 6 files to Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit
# WindowsPath('Z:/Met_Council/31000743A/Task 1 Consolidate Architecture/consolidate_architecture/Networks/standard_networks/v04/standard_networks/v04_scenario.yml')

# %% [markdown]
# # Alternate - start here for export

# %%
version_04_scenario = load_scenario(os.path.join(net_dir, 'v04', 'standard_networks', 'v04_scenario.yml'))
# Out:
# 2024-12-13 23:00:25, DEBUG: Loading Scenario from file: Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\v04_scenario.yml
# 2024-12-13 23:00:25, DEBUG: Reading nodes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\roadway\v04_node.geojson.
# 2024-12-13 23:00:25, DEBUG: Estimated read time: 4 seconds.
# 2024-12-13 23:00:44, DEBUG: Read 414426 nodes from file in 18.57.
# 2024-12-13 23:00:44, DEBUG: Turning node data into official nodes_df
# 2024-12-13 23:00:51, INFO: Read 414426 nodes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\roadway\v04_node.geojson in 25.76.
# 2024-12-13 23:00:52, INFO: Reading links from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\roadway\v04_link.json.
# 2024-12-13 23:00:52, DEBUG: Estimated read time: 4 minutes.
# 2024-12-13 23:02:09, DEBUG: Read 1061885 links in 77.38.
# 2024-12-13 23:02:09, DEBUG: Creating 1061885 links.
# 2024-12-13 23:02:10, DEBUG: Translating 334 records in lanes from v0 to v1 format.
# 2024-12-13 23:02:10, DEBUG: links_df.loc[complex_idx, prop]:
#                          1896    {'default': 0, 'timeofday': [{'value': 2, 'tim...
# 4910    {'default': 2, 'timeofday': [{'value': 1.0, 't...
# 5291    {'default': 5, 'timeofday': [{'value': 4.0, 't...
# 6617    {'default': 4, 'timeofday': [{'value': 3.0, 't...
# 6654    {'default': 3, 'timeofday': [{'value': 2.0, 't...
# Name: lanes, dtype: object
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 5.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 5.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:10, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:10, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 5.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 5.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 0.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 0.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 4.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 5.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 5.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 6.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 6.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 3.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [21600, 36000], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v0_item: {'time': [54000, 68400], 'value': 2.0}
# 2024-12-13 23:02:11, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 2.0}
# ...
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:13, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [21600, 36000], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['6:00:00', '10:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v0_item: {'time': [54000, 68400], 'value': 1}
# 2024-12-13 23:02:14, DEBUG: v1_item: {'timespan': ['15:00:00', '19:00:00'], 'value': 1}
# 2024-12-13 23:03:41, DEBUG: 1061885 new links.
# 2024-12-13 23:03:41, INFO: Read + transformed 1061885 links from             Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\roadway\v04_link.json in 169.15.
# 2024-12-13 23:03:53, INFO: Reading GTFS feed tables from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit
# 2024-12-13 23:03:53, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_frequencies.txt.
# 2024-12-13 23:03:53, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_routes.txt.
# 2024-12-13 23:03:53, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_shapes.txt.
# 2024-12-13 23:03:53, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_stops.txt.
# 2024-12-13 23:03:54, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_trips.txt.
# 2024-12-13 23:03:54, DEBUG: ...reading Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\transit\v04_stop_times.txt.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\network_wrangler\transit\io.py:81: DtypeWarning: Columns (1,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file)
# 2024-12-13 23:03:54, INFO: Initializing frequencies
# 2024-12-13 23:03:54, DEBUG: Validating + coercing value to frequencies
# 2024-12-13 23:03:54, DEBUG: PK table trips for specified FK                     frequencies.trip_id not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 23:03:54, INFO: Initializing routes
# 2024-12-13 23:03:54, DEBUG: Validating + coercing value to routes
# 2024-12-13 23:03:54, DEBUG: PK table agencies for specified FK                     routes.agency_id not in table list - skipping validation.
# 2024-12-13 23:03:54, DEBUG: Referencing table trips not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 23:03:54, INFO: Initializing shapes
# 2024-12-13 23:03:54, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:03:54, INFO: Initializing stops
# 2024-12-13 23:03:54, DEBUG: Validating + coercing value to stops
# 2024-12-13 23:03:54, DEBUG: PK table stops for specified FK                     stops.parent_station not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 23:03:54, DEBUG: Referencing table stops not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 23:03:54, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 23:03:54, INFO: Initializing trips
# 2024-12-13 23:03:54, DEBUG: Validating + coercing value to trips
# 2024-12-13 23:03:54, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 23:03:54, INFO: Initializing stop_times
# 2024-12-13 23:03:54, DEBUG: Validating + coercing value to stop_times
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\engines\pandas_engine.py:873: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   col = to_datetime_fn(col, **self.to_datetime_kwargs)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\engines\pandas_engine.py:873: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   col = to_datetime_fn(col, **self.to_datetime_kwargs)
# 2024-12-13 23:03:54, DEBUG: Creating new TransitNetwork.
# 2024-12-13 23:04:01, INFO: Creating Scenario
# 2024-12-13 23:04:04, DEBUG: Validating + coercing value to frequencies
# 2024-12-13 23:04:04, DEBUG: PK table trips for specified FK                     frequencies.trip_id not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 23:04:04, DEBUG: Validating + coercing value to routes
# 2024-12-13 23:04:04, DEBUG: PK table agencies for specified FK                     routes.agency_id not in table list - skipping validation.
# 2024-12-13 23:04:04, DEBUG: Referencing table trips not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 23:04:04, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:04:05, DEBUG: Validating + coercing value to stops
# 2024-12-13 23:04:05, DEBUG: PK table stops for specified FK                     stops.parent_station not in <class 'network_wrangler.transit.feed.feed.Feed'>-                      skipping validation.
# 2024-12-13 23:04:05, DEBUG: Referencing table stops not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 23:04:05, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 23:04:05, DEBUG: Validating + coercing value to trips
# 2024-12-13 23:04:05, DEBUG: Referencing table stop_times not yet set in                      <class 'network_wrangler.transit.feed.feed.Feed'> - skipping fk validation.
# 2024-12-13 23:04:05, DEBUG: Validating + coercing value to stop_times
# 2024-12-13 23:04:05, WARNING: Creating a deep copy of db object.            This will NOT update any references (e.g. from TransitNetwork)

# %% [markdown]
# # Make Travel Model Network

# %% [markdown]
# ### Add centroid and centroid connectors

# %%
r_net = metcouncil_roadway.add_centroid_and_centroid_connector(
    roadway_network =version_04_scenario.road_net,
    parameters = metcouncil_parameters,
    centroid_file = os.path.join(cc_dir, 'centroid_node.pickle'),
    centroid_connector_link_file = os.path.join(cc_dir, 'cc_link.pickle'),
    centroid_connector_shape_file = os.path.join(cc_dir, 'cc_shape.pickle'),
)
# Out:
# 2024-12-13 23:04:12, INFO: Adding centroid and centroid connector to standard network
# 2024-12-13 23:04:12, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 23:04:12, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler
# c:\Users\USYS671257\.conda\envs\wrangler\lib\pickle.py:1718: UserWarning: Unpickling a shapely <2.0 geometry object. Please save the pickle again; shapely 2.1 will not have this compatibility.
#   setstate(state)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\pickle.py:1718: UserWarning: Unpickling a shapely <2.0 geometry object. Please save the pickle again; shapely 2.1 will not have this compatibility.
#   setstate(state)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\pickle.py:1718: UserWarning: Unpickling a shapely <2.0 geometry object. Please save the pickle again; shapely 2.1 will not have this compatibility.
#   setstate(state)
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\met_council_wrangler\met_council_wrangler\metcouncil_roadway.py:2088: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   centroid_connector_link_gdf[c] = centroid_connector_link_gdf[c].replace(
# 2024-12-13 23:04:16, DEBUG: Reading shapes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\roadway\v04_shape.geojson.
# 2024-12-13 23:04:16, DEBUG: Estimated read time: 8 seconds.
# 2024-12-13 23:04:44, DEBUG: Read 556324 shapes from file in 28.7.
# 2024-12-13 23:04:44, DEBUG: Creating 556324 shapes.
# 2024-12-13 23:04:46, INFO: Read 556324 shapes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\Networks\standard_networks\v04\standard_networks\roadway\v04_shape.geojson in 30.12.
# 2024-12-13 23:04:47, DEBUG: Creating 577228 shapes.
# 2024-12-13 23:04:48, INFO: Finished adding centroid and centroid connectors

# %%
centroids_df = r_net.links_df[r_net.links_df["centroidconnect"] == True].copy()

centroids_df["bike_access"].value_counts()
# Out:
# bike_access
# True     24044
# False    17830
# Name: count, dtype: int64

# %% [markdown]
# ### Add Rail access and egress links

# %%
r_net = metcouncil_roadway.add_rail_ae_connections(
    r_net,
    metcouncil_parameters,
    exclude_rail_node_id = [417275, 417255]
)
# Out:
# 2024-12-13 23:04:50, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 23:04:50, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler
# 2024-12-13 23:04:50, INFO: Creating rail access and egress connection links
# 2024-12-13 23:04:50, INFO: Exclude rail node id: [417275, 417255]
# 2024-12-13 23:04:57, DEBUG: Creating 577488 shapes.

# %%
m_net = metcouncil_roadway.roadway_standard_to_met_council_network(
    r_net,
    metcouncil_parameters    
)
# Out:
# 2024-12-13 23:04:59, INFO: Renaming roadway attributes to be consistent with what metcouncil's model is expecting
# 2024-12-13 23:04:59, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 23:04:59, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler
# 2024-12-13 23:04:59, INFO: Creating managed lane network.
# 2024-12-13 23:04:59, INFO: Separating managed lane links from general purpose links
# 2024-12-13 23:05:07, DEBUG: Copying 325 links.
# 2024-12-13 23:05:07, DEBUG: Separated ML links:
#   no parallel ML: 1103632
#   parallel GP: 325
#   separate ML: 325
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:05:10, DEBUG: Creating access and egress dummy connector links
# 2024-12-13 23:05:10, DEBUG: Creating 650 links.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\geopandas\array.py:1638: UserWarning: CRS not set for some of the concatenation inputs. Setting output's CRS as NAD83 (the single non-null crs provided).
#   return GeometryArray(data, crs=_get_common_crs(to_concat))
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\network_wrangler\roadway\links\filters.py:212: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return links_df.loc[links_df["ML_access_point"].fillna(False)]
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\network_wrangler\roadway\links\filters.py:219: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return links_df.loc[links_df["ML_egress_point"].fillna(False)]
# 2024-12-13 23:05:11, DEBUG: 650 new links.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:05:11, DEBUG: access_egress_df['geometry']:
#  model_link_id_idx
# 3005914    LINESTRING (-93.18874 45.1355, -93.18887 45.1355)
# 3006295    LINESTRING (-93.28277 45.00835, -93.28289 45.0...
# 3007622    LINESTRING (-93.28829 44.77888, -93.28817 44.7...
# 3007659    LINESTRING (-93.30257 44.86175, -93.30257 44.8...
# 3008853    LINESTRING (-93.29613 44.8355, -93.29602 44.83...
#                                  ...
# 4902128    LINESTRING (-93.2881 45.08166, -93.28798 45.08...
# 4902129    LINESTRING (-93.28757 45.08233, -93.28769 45.0...
# 4902130    LINESTRING (-93.28692 45.07417, -93.2868 45.07...
# 4902131    LINESTRING (-93.28655 45.07513, -93.28667 45.0...
# 4902132    LINESTRING (-93.28637 45.07424, -93.28649 45.0...
# Name: geometry, Length: 650, dtype: geometry
# 2024-12-13 23:05:12, DEBUG: Access Egress Links Created: 650
# 2024-12-13 23:05:16, INFO: Distance Variable 'distance' already in network. Returning without overwriting.
# 2024-12-13 23:05:16, INFO: Finished creating ML lanes variable: ML_lanes
# 2024-12-13 23:05:16, INFO: Finished creating hov corridor variable: segment_id
# 2024-12-13 23:05:16, INFO: Managed Variable 'managed' already in network. Returning without overwriting.
# 2024-12-13 23:05:16, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 23:05:16, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler
# 2024-12-13 23:05:16, INFO: Area Type Variable 'area_type' already in network. But some records are missing. Calcualting the missing values without overwriting existing.
# 2024-12-13 23:05:16, INFO: Calculating Area Type from Spatial Data and adding as roadway network variable: area_type
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\met_council_wrangler\met_council_wrangler\metcouncil_roadway.py:284: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids_gdf["geometry"] = centroids_gdf["geometry"].centroid
# 2024-12-13 23:05:37, DEBUG: Reading Area Type Shapefile Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler\metcouncil_data\area_type\ThriveMSP2040CommunityDesignation.shp
# 2024-12-13 23:05:47, DEBUG: Area Type Codes Used: {23: 4, 24: 3, 25: 2, 35: 2, 36: 1, 41: 1, 51: 1, 52: 1, 53: 1, 60: 1}
# 2024-12-13 23:05:48, DEBUG: Downtown Area Type used boundary file: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler\metcouncil_data\area_type\downtownzones_TAZ.shp
# 2024-12-13 23:05:48, INFO: Finished Calculating Area Type from Spatial Data into variable: area_type
# 2024-12-13 23:05:51, INFO: Overwriting existing County Variable 'county' already in network
# 2024-12-13 23:05:51, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 23:05:51, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler
# 2024-12-13 23:05:51, INFO: Adding roadway network variable for county using a spatial join with: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler\metcouncil_data\county\cb_2017_us_county_5m.shp
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\met_council_wrangler\met_council_wrangler\metcouncil_roadway.py:442: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroids_gdf["geometry"] = centroids_gdf["geometry"].centroid
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\met_council_wrangler\met_council_wrangler\metcouncil_roadway.py:453: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: EPSG:4269
#
#   joined_gdf = gpd.sjoin(
# 2024-12-13 23:06:02, INFO: Finished Calculating county variable: county
# 2024-12-13 23:06:03, INFO: Calculating MPO as roadway network variable: mpo
# 2024-12-13 23:06:03, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 23:06:03, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler
# 2024-12-13 23:06:03, DEBUG: MPO Counties: [,1,,, ,3,,, ,4,,, ,5,,, ,6,,, ,7,,, ,2,]
# 2024-12-13 23:06:03, INFO: Finished calculating MPO variable: mpo
# 2024-12-13 23:06:03, INFO: Adding Counts
# 2024-12-13 23:06:03, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 23:06:03, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler
# 2024-12-13 23:06:03, DEBUG: Adding MNDOT Counts using
# - shst file: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler\metcouncil_data\count_mn\mn_count_ShSt_API_match.csv
# - shp file: AADT_mn
# - as network variable: AADT
# 2024-12-13 23:06:03, INFO: Adding Variable AADT using Shared Streets Reference from Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler\metcouncil_data\count_mn\mn_count_ShSt_API_match.csv
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\roadway.py:521: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   join_gdf[shst_csv_variable].fillna(0, inplace=True)
# 2024-12-13 23:06:13, INFO: Added variable: AADT using Shared Streets Reference
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\roadway.py:556: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   roadway_net.links_df[network_variable].fillna(0, inplace=True)
# 2024-12-13 23:06:13, DEBUG: Adding WiDot Counts using
# - shst file: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler\metcouncil_data\Wisconsin_Lanes_Counts_Median\wi_count_ShSt_API_match.csv
# - shp file: AADT_wi
# - as network variable: AADT
# 2024-12-13 23:06:13, INFO: Adding Variable AADT using Shared Streets Reference from Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler\metcouncil_data\Wisconsin_Lanes_Counts_Median\wi_count_ShSt_API_match.csv
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\roadway.py:521: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   join_gdf[shst_csv_variable].fillna(0, inplace=True)
# 2024-12-13 23:06:17, INFO: Added variable: AADT using Shared Streets Reference
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\roadway.py:556: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   roadway_net.links_df[network_variable].fillna(0, inplace=True)
# 2024-12-13 23:06:18, INFO: Finished adding counts variable: AADT
# 2024-12-13 23:06:18, INFO: Filling nan for network from network wrangler
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\roadway.py:666: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   roadway_net.links_df[x].fillna(0, inplace=True)
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\roadway.py:676: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   roadway_net.nodes_df[x].fillna(0, inplace=True)
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\roadway.py:678: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   roadway_net.nodes_df[x].fillna("", inplace=True)
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\roadway.py:678: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   roadway_net.nodes_df[x].fillna("", inplace=True)
# 2024-12-13 23:06:34, INFO: Splitting variables by time period and category
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:06:52, DEBUG: No scoped values trn_priority. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:07:12, DEBUG: No scoped values trn_priority. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:07:31, DEBUG: No scoped values trn_priority. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:07:50, DEBUG: No scoped values trn_priority. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:08:09, DEBUG: No scoped values trn_priority. Returning default.
# 2024-12-13 23:08:09, WARNING: Specified variable to split: ttime_assert not in network variables: Index(['lanes', 'egress', 'managed', 'model_link_id', 'name', 'access', 'GP_B',
#        'MNPASS_CODE', 'rail_only', 'projects', 'bike_access',
#        'ML_access_point', 'roadway', 'sc_lanes', 'geometry', 'walk_access',
#        'GP_A', 'B', 'source_geometry', 'ML_egress_point', 'A', 'ref',
#        'source_model_link_id', 'drive_access', 'distance', 'bus_only',
#        'shape_id', 'price', 'ML_projects', 'osm_link_id', 'locationReferences',
#        'shstReferenceId', 'shstGeometryId', 'fromIntersectionId',
#        'toIntersectionId', 'u', 'v', 'nodeIds', 'wayId', 'roadClass', 'oneWay',
#        'roundabout', 'link', 'oneway', 'lanes_osm', 'highway', 'service',
#        'width', 'maxspeed', 'junction', 'bridge', 'tunnel', 'landuse', 'area',
#        'key', 'forward', 'backReferenceId', 'metadata', 'source', 'county',
#        'length', 'centroidconnect', 'assign_group', 'roadway_class',
#        'trn_priority', 'area_type', 'ramp_flag', 'bike', 'walk', 'MNPASS_PAY',
#        'GP_model_link_id', 'segment_id', 'mpo', 'AADT', 'count_AM', 'count_MD',
#        'count_PM', 'count_NT', 'count_daily', 'count_year', 'trn_priority_EA',
#        'trn_priority_AM', 'trn_priority_MD', 'trn_priority_PM',
#        'trn_priority_NT'],
#       dtype='object'). Returning 0.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:08:30, DEBUG: Exploded Records:
#          model_link_id  lanes  \
# 0              3004914      0
# 1              3005295      0
# 2              3006622      0
# 3              3006659      0
# 3              3006659      0
# ...                ...    ...
# 453655          453518      0
# 1061829        1950010      0
# 1061830        1950011      0
# 1061831        1950012      0
# 1061832        1950013      0
#
#                                                   sc_lanes
# 0        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 2        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# ...                                                    ...
# 453655   {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# 1061829  {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1061830  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061831  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061832  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
#
# [745 rows x 3 columns]
# 2024-12-13 23:08:31, DEBUG: Exploded columns:
#          model_link_id  value              timespan
# 0              3004914    1.0   [6:00:00, 10:00:00]
# 1              3005295    1.0   [6:00:00, 10:00:00]
# 2              3006622    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0  [15:00:00, 19:00:00]
# ...                ...    ...                   ...
# 453655          453518    1.0  [15:00:00, 19:00:00]
# 1061829        1950010    1.0   [6:00:00, 10:00:00]
# 1061830        1950011    2.0   [6:00:00, 10:00:00]
# 1061831        1950012    2.0   [6:00:00, 10:00:00]
# 1061832        1950013    2.0   [6:00:00, 10:00:00]
#
# [745 rows x 3 columns]
# 2024-12-13 23:08:31, DEBUG: exp_df:
#          model_link_id  scoped              timespan category  \
# 0              3004914     1.0   [6:00:00, 10:00:00]      any
# 1              3005295     1.0   [6:00:00, 10:00:00]      any
# 2              3006622     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0  [15:00:00, 19:00:00]      any
# ...                ...     ...                   ...      ...
# 453655          453518     1.0  [15:00:00, 19:00:00]      any
# 1061829        1950010     1.0   [6:00:00, 10:00:00]      any
# 1061830        1950011     2.0   [6:00:00, 10:00:00]      any
# 1061831        1950012     2.0   [6:00:00, 10:00:00]      any
# 1061832        1950013     2.0   [6:00:00, 10:00:00]      any
#
#                  start_time            end_time
# 0       2024-12-13 06:00:00 2024-12-13 10:00:00
# 1       2024-12-13 06:00:00 2024-12-13 10:00:00
# 2       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 15:00:00 2024-12-13 19:00:00
# ...                     ...                 ...
# 453655  2024-12-13 15:00:00 2024-12-13 19:00:00
# 1061829 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061830 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061831 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061832 2024-12-13 06:00:00 2024-12-13 10:00:00
#
# [745 rows x 6 columns]
# 2024-12-13 23:08:31, DEBUG: overlap_df:
# Empty DataFrame
# Columns: [model_link_id, scoped, timespan, category, start_time, end_time, overlap_duration]
# Index: []
# 2024-12-13 23:08:31, DEBUG: match_df:
# Empty DataFrame
# Columns: [model_link_id, scoped, timespan, category, start_time, end_time, overlap_duration]
# Index: []
# 2024-12-13 23:08:31, DEBUG: result_df[prop_name]:
# Series([], Name: lanes, dtype: int64)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\network_wrangler\utils\time.py:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_end.loc[orig_df["end_time"] < orig_df["start_time"]] += pd.Timedelta(days=1)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:08:51, DEBUG: Exploded Records:
#          model_link_id  lanes  \
# 0              3004914      0
# 1              3005295      0
# 2              3006622      0
# 3              3006659      0
# 3              3006659      0
# ...                ...    ...
# 453655          453518      0
# 1061829        1950010      0
# 1061830        1950011      0
# 1061831        1950012      0
# 1061832        1950013      0
#
#                                                   sc_lanes
# 0        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 2        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# ...                                                    ...
# 453655   {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# 1061829  {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1061830  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061831  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061832  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
#
# [745 rows x 3 columns]
# 2024-12-13 23:08:51, DEBUG: Exploded columns:
#          model_link_id  value              timespan
# 0              3004914    1.0   [6:00:00, 10:00:00]
# 1              3005295    1.0   [6:00:00, 10:00:00]
# 2              3006622    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0  [15:00:00, 19:00:00]
# ...                ...    ...                   ...
# 453655          453518    1.0  [15:00:00, 19:00:00]
# 1061829        1950010    1.0   [6:00:00, 10:00:00]
# 1061830        1950011    2.0   [6:00:00, 10:00:00]
# 1061831        1950012    2.0   [6:00:00, 10:00:00]
# 1061832        1950013    2.0   [6:00:00, 10:00:00]
#
# [745 rows x 3 columns]
# 2024-12-13 23:08:51, DEBUG: exp_df:
#          model_link_id  scoped              timespan category  \
# 0              3004914     1.0   [6:00:00, 10:00:00]      any
# 1              3005295     1.0   [6:00:00, 10:00:00]      any
# 2              3006622     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0  [15:00:00, 19:00:00]      any
# ...                ...     ...                   ...      ...
# 453655          453518     1.0  [15:00:00, 19:00:00]      any
# 1061829        1950010     1.0   [6:00:00, 10:00:00]      any
# 1061830        1950011     2.0   [6:00:00, 10:00:00]      any
# 1061831        1950012     2.0   [6:00:00, 10:00:00]      any
# 1061832        1950013     2.0   [6:00:00, 10:00:00]      any
#
#                  start_time            end_time
# 0       2024-12-13 06:00:00 2024-12-13 10:00:00
# 1       2024-12-13 06:00:00 2024-12-13 10:00:00
# 2       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 15:00:00 2024-12-13 19:00:00
# ...                     ...                 ...
# 453655  2024-12-13 15:00:00 2024-12-13 19:00:00
# 1061829 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061830 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061831 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061832 2024-12-13 06:00:00 2024-12-13 10:00:00
#
# [745 rows x 6 columns]
# 2024-12-13 23:08:51, DEBUG: overlap_df:
#          model_link_id  scoped             timespan category  \
# 0              3004914     1.0  [6:00:00, 10:00:00]      any
# 1              3005295     1.0  [6:00:00, 10:00:00]      any
# 2              3006622     1.0  [6:00:00, 10:00:00]      any
# 3              3006659     1.0  [6:00:00, 10:00:00]      any
# 4              3007853     1.0  [6:00:00, 10:00:00]      any
# ...                ...     ...                  ...      ...
# 276899          276573     1.0  [6:00:00, 10:00:00]      any
# 1061829        1950010     1.0  [6:00:00, 10:00:00]      any
# 1061830        1950011     2.0  [6:00:00, 10:00:00]      any
# 1061831        1950012     2.0  [6:00:00, 10:00:00]      any
# 1061832        1950013     2.0  [6:00:00, 10:00:00]      any
#
#                  start_time            end_time  overlap_duration
# 0       2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
# 1       2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
# 2       2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
# 3       2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
# 4       2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
# ...                     ...                 ...               ...
# 276899  2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
# 1061829 2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
# 1061830 2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
# 1061831 2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
# 1061832 2024-12-13 06:00:00 2024-12-13 10:00:00             240.0
#
# [387 rows x 7 columns]
# 2024-12-13 23:08:51, DEBUG: match_df:
#      model_link_id  scoped             timespan category          start_time  \
# 325           4914     1.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
# 326           5295     4.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
# 327           6622     3.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
# 328           6659     2.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
# 329           7853     3.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
# ..             ...     ...                  ...      ...                 ...
# 313        4900119     1.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
# 314        4900122     1.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
# 317        4900125     1.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
# 320        4900128     1.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
# 322        4900130     1.0  [6:00:00, 10:00:00]      any 2024-12-13 06:00:00
#
#                end_time  overlap_duration
# 325 2024-12-13 10:00:00             240.0
# 326 2024-12-13 10:00:00             240.0
# 327 2024-12-13 10:00:00             240.0
# 328 2024-12-13 10:00:00             240.0
# 329 2024-12-13 10:00:00             240.0
# ..                  ...               ...
# 313 2024-12-13 10:00:00             240.0
# 314 2024-12-13 10:00:00             240.0
# 317 2024-12-13 10:00:00             240.0
# 320 2024-12-13 10:00:00             240.0
# 322 2024-12-13 10:00:00             240.0
#
# [387 rows x 7 columns]
# 2024-12-13 23:08:51, DEBUG: result_df[prop_name]:
# 325    1
# 326    4
# 327    3
# 328    2
# 329    3
#       ..
# 313    1
# 314    1
# 317    1
# 320    1
# 322    1
# Name: lanes, Length: 387, dtype: int64
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\network_wrangler\utils\time.py:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_end.loc[orig_df["end_time"] < orig_df["start_time"]] += pd.Timedelta(days=1)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:09:10, DEBUG: Exploded Records:
#          model_link_id  lanes  \
# 0              3004914      0
# 1              3005295      0
# 2              3006622      0
# 3              3006659      0
# 3              3006659      0
# ...                ...    ...
# 453655          453518      0
# 1061829        1950010      0
# 1061830        1950011      0
# 1061831        1950012      0
# 1061832        1950013      0
#
#                                                   sc_lanes
# 0        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 2        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# ...                                                    ...
# 453655   {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# 1061829  {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1061830  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061831  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061832  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
#
# [745 rows x 3 columns]
# 2024-12-13 23:09:10, DEBUG: Exploded columns:
#          model_link_id  value              timespan
# 0              3004914    1.0   [6:00:00, 10:00:00]
# 1              3005295    1.0   [6:00:00, 10:00:00]
# 2              3006622    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0  [15:00:00, 19:00:00]
# ...                ...    ...                   ...
# 453655          453518    1.0  [15:00:00, 19:00:00]
# 1061829        1950010    1.0   [6:00:00, 10:00:00]
# 1061830        1950011    2.0   [6:00:00, 10:00:00]
# 1061831        1950012    2.0   [6:00:00, 10:00:00]
# 1061832        1950013    2.0   [6:00:00, 10:00:00]
#
# [745 rows x 3 columns]
# 2024-12-13 23:09:10, DEBUG: exp_df:
#          model_link_id  scoped              timespan category  \
# 0              3004914     1.0   [6:00:00, 10:00:00]      any
# 1              3005295     1.0   [6:00:00, 10:00:00]      any
# 2              3006622     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0  [15:00:00, 19:00:00]      any
# ...                ...     ...                   ...      ...
# 453655          453518     1.0  [15:00:00, 19:00:00]      any
# 1061829        1950010     1.0   [6:00:00, 10:00:00]      any
# 1061830        1950011     2.0   [6:00:00, 10:00:00]      any
# 1061831        1950012     2.0   [6:00:00, 10:00:00]      any
# 1061832        1950013     2.0   [6:00:00, 10:00:00]      any
#
#                  start_time            end_time
# 0       2024-12-13 06:00:00 2024-12-13 10:00:00
# 1       2024-12-13 06:00:00 2024-12-13 10:00:00
# 2       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 15:00:00 2024-12-13 19:00:00
# ...                     ...                 ...
# 453655  2024-12-13 15:00:00 2024-12-13 19:00:00
# 1061829 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061830 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061831 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061832 2024-12-13 06:00:00 2024-12-13 10:00:00
#
# [745 rows x 6 columns]
# 2024-12-13 23:09:10, DEBUG: overlap_df:
# Empty DataFrame
# Columns: [model_link_id, scoped, timespan, category, start_time, end_time, overlap_duration]
# Index: []
# 2024-12-13 23:09:10, DEBUG: match_df:
# Empty DataFrame
# Columns: [model_link_id, scoped, timespan, category, start_time, end_time, overlap_duration]
# Index: []
# 2024-12-13 23:09:10, DEBUG: result_df[prop_name]:
# Series([], Name: lanes, dtype: int64)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\network_wrangler\utils\time.py:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_end.loc[orig_df["end_time"] < orig_df["start_time"]] += pd.Timedelta(days=1)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:09:29, DEBUG: Exploded Records:
#          model_link_id  lanes  \
# 0              3004914      0
# 1              3005295      0
# 2              3006622      0
# 3              3006659      0
# 3              3006659      0
# ...                ...    ...
# 453655          453518      0
# 1061829        1950010      0
# 1061830        1950011      0
# 1061831        1950012      0
# 1061832        1950013      0
#
#                                                   sc_lanes
# 0        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 2        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# ...                                                    ...
# 453655   {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# 1061829  {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1061830  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061831  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061832  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
#
# [745 rows x 3 columns]
# 2024-12-13 23:09:29, DEBUG: Exploded columns:
#          model_link_id  value              timespan
# 0              3004914    1.0   [6:00:00, 10:00:00]
# 1              3005295    1.0   [6:00:00, 10:00:00]
# 2              3006622    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0  [15:00:00, 19:00:00]
# ...                ...    ...                   ...
# 453655          453518    1.0  [15:00:00, 19:00:00]
# 1061829        1950010    1.0   [6:00:00, 10:00:00]
# 1061830        1950011    2.0   [6:00:00, 10:00:00]
# 1061831        1950012    2.0   [6:00:00, 10:00:00]
# 1061832        1950013    2.0   [6:00:00, 10:00:00]
#
# [745 rows x 3 columns]
# 2024-12-13 23:09:29, DEBUG: exp_df:
#          model_link_id  scoped              timespan category  \
# 0              3004914     1.0   [6:00:00, 10:00:00]      any
# 1              3005295     1.0   [6:00:00, 10:00:00]      any
# 2              3006622     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0  [15:00:00, 19:00:00]      any
# ...                ...     ...                   ...      ...
# 453655          453518     1.0  [15:00:00, 19:00:00]      any
# 1061829        1950010     1.0   [6:00:00, 10:00:00]      any
# 1061830        1950011     2.0   [6:00:00, 10:00:00]      any
# 1061831        1950012     2.0   [6:00:00, 10:00:00]      any
# 1061832        1950013     2.0   [6:00:00, 10:00:00]      any
#
#                  start_time            end_time
# 0       2024-12-13 06:00:00 2024-12-13 10:00:00
# 1       2024-12-13 06:00:00 2024-12-13 10:00:00
# 2       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 15:00:00 2024-12-13 19:00:00
# ...                     ...                 ...
# 453655  2024-12-13 15:00:00 2024-12-13 19:00:00
# 1061829 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061830 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061831 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061832 2024-12-13 06:00:00 2024-12-13 10:00:00
#
# [745 rows x 6 columns]
# 2024-12-13 23:09:29, DEBUG: overlap_df:
#         model_link_id  scoped              timespan category  \
# 3             3006659     1.0  [15:00:00, 19:00:00]      any
# 5             3009074     1.0  [15:00:00, 19:00:00]      any
# 6             3010377     1.0  [15:00:00, 19:00:00]      any
# 12            3024237     1.0  [15:00:00, 19:00:00]      any
# 15            3027252     1.0  [15:00:00, 19:00:00]      any
# ...               ...     ...                   ...      ...
# 649           1900132     2.0  [15:00:00, 19:00:00]      any
# 2546             1898     2.0  [15:00:00, 19:00:00]      any
# 128969         128466     2.0  [15:00:00, 19:00:00]      any
# 305833         305528     2.0  [15:00:00, 19:00:00]      any
# 453655         453518     1.0  [15:00:00, 19:00:00]      any
#
#                 start_time            end_time  overlap_duration
# 3      2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 5      2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 6      2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 12     2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 15     2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# ...                    ...                 ...               ...
# 649    2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 2546   2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 128969 2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 305833 2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 453655 2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
#
# [358 rows x 7 columns]
# 2024-12-13 23:09:29, DEBUG: match_df:
#       model_link_id  scoped              timespan category  \
# 2546           1898     2.0  [15:00:00, 19:00:00]      any
# 328            6659     2.0  [15:00:00, 19:00:00]      any
# 330            9074     4.0  [15:00:00, 19:00:00]      any
# 331           10377     2.0  [15:00:00, 19:00:00]      any
# 337           24237     5.0  [15:00:00, 19:00:00]      any
# ...             ...     ...                   ...      ...
# 318         4900126     1.0  [15:00:00, 19:00:00]      any
# 319         4900127     1.0  [15:00:00, 19:00:00]      any
# 321         4900129     1.0  [15:00:00, 19:00:00]      any
# 323         4900131     1.0  [15:00:00, 19:00:00]      any
# 324         4900132     1.0  [15:00:00, 19:00:00]      any
#
#               start_time            end_time  overlap_duration
# 2546 2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 328  2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 330  2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 331  2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 337  2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# ...                  ...                 ...               ...
# 318  2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 319  2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 321  2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 323  2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
# 324  2024-12-13 15:00:00 2024-12-13 19:00:00             240.0
#
# [358 rows x 7 columns]
# 2024-12-13 23:09:29, DEBUG: result_df[prop_name]:
# 2546    2
# 328     2
# 330     4
# 331     2
# 337     5
#        ..
# 318     1
# 319     1
# 321     1
# 323     1
# 324     1
# Name: lanes, Length: 358, dtype: int64
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\network_wrangler\utils\time.py:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_end.loc[orig_df["end_time"] < orig_df["start_time"]] += pd.Timedelta(days=1)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:09:48, DEBUG: Exploded Records:
#          model_link_id  lanes  \
# 0              3004914      0
# 1              3005295      0
# 2              3006622      0
# 3              3006659      0
# 3              3006659      0
# ...                ...    ...
# 453655          453518      0
# 1061829        1950010      0
# 1061830        1950011      0
# 1061831        1950012      0
# 1061832        1950013      0
#
#                                                   sc_lanes
# 0        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 2        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 3        {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# ...                                                    ...
# 453655   {'value': 1, 'timespan': ['15:00:00', '19:00:0...
# 1061829  {'value': 1, 'timespan': ['6:00:00', '10:00:00']}
# 1061830  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061831  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
# 1061832  {'value': 2, 'timespan': ['6:00:00', '10:00:00']}
#
# [745 rows x 3 columns]
# 2024-12-13 23:09:48, DEBUG: Exploded columns:
#          model_link_id  value              timespan
# 0              3004914    1.0   [6:00:00, 10:00:00]
# 1              3005295    1.0   [6:00:00, 10:00:00]
# 2              3006622    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0   [6:00:00, 10:00:00]
# 3              3006659    1.0  [15:00:00, 19:00:00]
# ...                ...    ...                   ...
# 453655          453518    1.0  [15:00:00, 19:00:00]
# 1061829        1950010    1.0   [6:00:00, 10:00:00]
# 1061830        1950011    2.0   [6:00:00, 10:00:00]
# 1061831        1950012    2.0   [6:00:00, 10:00:00]
# 1061832        1950013    2.0   [6:00:00, 10:00:00]
#
# [745 rows x 3 columns]
# 2024-12-13 23:09:48, DEBUG: exp_df:
#          model_link_id  scoped              timespan category  \
# 0              3004914     1.0   [6:00:00, 10:00:00]      any
# 1              3005295     1.0   [6:00:00, 10:00:00]      any
# 2              3006622     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0   [6:00:00, 10:00:00]      any
# 3              3006659     1.0  [15:00:00, 19:00:00]      any
# ...                ...     ...                   ...      ...
# 453655          453518     1.0  [15:00:00, 19:00:00]      any
# 1061829        1950010     1.0   [6:00:00, 10:00:00]      any
# 1061830        1950011     2.0   [6:00:00, 10:00:00]      any
# 1061831        1950012     2.0   [6:00:00, 10:00:00]      any
# 1061832        1950013     2.0   [6:00:00, 10:00:00]      any
#
#                  start_time            end_time
# 0       2024-12-13 06:00:00 2024-12-13 10:00:00
# 1       2024-12-13 06:00:00 2024-12-13 10:00:00
# 2       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 06:00:00 2024-12-13 10:00:00
# 3       2024-12-13 15:00:00 2024-12-13 19:00:00
# ...                     ...                 ...
# 453655  2024-12-13 15:00:00 2024-12-13 19:00:00
# 1061829 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061830 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061831 2024-12-13 06:00:00 2024-12-13 10:00:00
# 1061832 2024-12-13 06:00:00 2024-12-13 10:00:00
#
# [745 rows x 6 columns]
# 2024-12-13 23:09:48, WARNING: Timespan is not in increasing order: ['19:00', '3:00'].            End time will be treated as next day.
# 2024-12-13 23:09:48, DEBUG: overlap_df:
# Empty DataFrame
# Columns: [model_link_id, scoped, timespan, category, start_time, end_time, overlap_duration]
# Index: []
# 2024-12-13 23:09:48, DEBUG: match_df:
# Empty DataFrame
# Columns: [model_link_id, scoped, timespan, category, start_time, end_time, overlap_duration]
# Index: []
# 2024-12-13 23:09:48, DEBUG: result_df[prop_name]:
# Series([], Name: lanes, dtype: int64)
# 2024-12-13 23:09:48, WARNING: Specified variable to split: ML_lanes not in network variables: Index(['lanes', 'egress', 'managed', 'model_link_id', 'name', 'access', 'GP_B',
#        'MNPASS_CODE', 'rail_only', 'projects', 'bike_access',
#        'ML_access_point', 'roadway', 'sc_lanes', 'geometry', 'walk_access',
#        'GP_A', 'B', 'source_geometry', 'ML_egress_point', 'A', 'ref',
#        'source_model_link_id', 'drive_access', 'distance', 'bus_only',
#        'shape_id', 'price', 'ML_projects', 'osm_link_id', 'locationReferences',
#        'shstReferenceId', 'shstGeometryId', 'fromIntersectionId',
#        'toIntersectionId', 'u', 'v', 'nodeIds', 'wayId', 'roadClass', 'oneWay',
#        'roundabout', 'link', 'oneway', 'lanes_osm', 'highway', 'service',
#        'width', 'maxspeed', 'junction', 'bridge', 'tunnel', 'landuse', 'area',
#        'key', 'forward', 'backReferenceId', 'metadata', 'source', 'county',
#        'length', 'centroidconnect', 'assign_group', 'roadway_class',
#        'trn_priority', 'area_type', 'ramp_flag', 'bike', 'walk', 'MNPASS_PAY',
#        'GP_model_link_id', 'segment_id', 'mpo', 'AADT', 'count_AM', 'count_MD',
#        'count_PM', 'count_NT', 'count_daily', 'count_year', 'trn_priority_EA',
#        'trn_priority_AM', 'trn_priority_MD', 'trn_priority_PM',
#        'trn_priority_NT', 'ttime_assert_EA', 'ttime_assert_AM',
#        'ttime_assert_MD', 'ttime_assert_PM', 'ttime_assert_NT', 'lanes_EA',
#        'lanes_AM', 'lanes_MD', 'lanes_PM', 'lanes_NT'],
#       dtype='object'). Returning 0.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\network_wrangler\utils\time.py:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_end.loc[orig_df["end_time"] < orig_df["start_time"]] += pd.Timedelta(days=1)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:10:07, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:10:25, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:10:44, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:11:03, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:11:24, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:11:43, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:12:03, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:12:23, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:12:42, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:13:02, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:13:22, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:13:41, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:14:01, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:14:21, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:14:41, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:15:00, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:15:22, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:15:41, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:16:00, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:16:20, DEBUG: No scoped values price. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:16:41, DEBUG: No scoped values access. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:17:00, DEBUG: No scoped values access. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:17:20, DEBUG: No scoped values access. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:17:41, DEBUG: No scoped values access. Returning default.
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pandera\backends\pandas\container.py:544: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   check_obj[col_name] = check_obj[col_name].fillna(
# 2024-12-13 23:18:01, DEBUG: No scoped values access. Returning default.
# 2024-12-13 23:18:01, INFO: Converting variable type to MetCouncil standard
# 2024-12-13 23:18:01, INFO: Converting variable type to MetCouncil standard
# 2024-12-13 23:18:15, INFO: Setting Coordinate Reference System to EPSG 26915

# %%
# check if missing IDs
# centroids does not have osm and shst IDs
# centroid connectors does not have osm and shst IDs

# if node missing shst id
print(m_net.nodes_df.shst_node_id.isnull().sum())
print(m_net.nodes_df.shst_node_id.nunique())

# if node missing model node id
print(m_net.nodes_df.model_node_id.nunique())

# if link missing 
print(m_net.links_df.shstReferenceId.isnull().sum())
print(m_net.links_df.shstReferenceId.nunique())
print(m_net.links_df.model_link_id.nunique())

# if link missing node id
print(m_net.links_df.fromIntersectionId.isnull().sum())
print(m_net.links_df.toIntersectionId.isnull().sum())
# Out:
# 0
# 414221
# 417793
# 43687
# 1061245
# 1104932
# 22781
# 22781

# %%
m_net.nodes_df.columns
# Out:
# Index(['model_node_id', 'X', 'Y', 'osm_node_id', 'projects', 'shst_node_id',
#        'drive_access', 'walk_access', 'bike_access', 'rail_only', 'geometry',
#        'GP_model_node_id', 'county', 'N'],
#       dtype='object')

# %%
m_net.links_df.columns
# Out:
# Index(['lanes', 'egress', 'managed', 'model_link_id', 'name', 'access', 'GP_B',
#        'MNPASS_CODE', 'rail_only', 'projects',
#        ...
#        'price_sov_NT', 'price_hov2_NT', 'price_hov3_NT', 'price_truck_NT',
#        'access_EA', 'access_AM', 'access_MD', 'access_PM', 'access_NT',
#        'geometry'],
#       dtype='object', length=125)

# %%
#check column datatype .dtypes
m_net.links_df.MNPASS_CODE.dtype
# Out:
# dtype('int32')

# %% [markdown]
# ## Populate MnPASS PAY Links

# %%
# step 0: make a copy of the metcouncil links dataframe
input_df=(m_net.links_df).copy()

# %%
# step 1: select managed lanes with mnpass code
ML_mnpasscode_df = input_df[
    input_df["MNPASS_CODE"].isin(range(1,100)) & 
    (input_df["managed"] == 1) # excludes the reversible section on i-394 since they are not coded as paralel managed lanes
].copy().reset_index(drop = True)

# %%
ML_mnpasscode_df.managed.value_counts(dropna=False)
# Out:
# managed
# 1    325
# Name: count, dtype: int64

# %%
# step 2: select the ML access connectors
# we know that the B node of the access connector is the A node of the managed lane
acc_con_df = input_df[input_df["B"].isin(ML_mnpasscode_df["A"].unique())].copy().reset_index(drop=True)
acc_con_df = acc_con_df[acc_con_df["managed"] == 0].copy().reset_index(drop=True)

# %%
acc_con_df.model_link_id.nunique()
# Out:
# 325

# %%
# step 3: create a dataframe with the connectors and the MNPASS_PAY value
# match access connector with the ML lane based on: B node of the connector = A node of the ML lane
ML_mnpasscode_df = ML_mnpasscode_df[["A", "MNPASS_CODE"]].copy().reset_index(drop=True).rename(columns = {"A": "B", "MNPASS_CODE": "MNPASS_PAY_UPDATE"})
# creates 1-on-1 join between the access connector and the ML lane
join_code_df = ML_mnpasscode_df.merge(acc_con_df[['A','B']].drop_duplicates(), on='B', how='left')

updated_acc_con_df = pd.merge(acc_con_df, join_code_df, how="left", on=["A", "B"])
updated_acc_con_df = updated_acc_con_df[["A", "B", "MNPASS_PAY_UPDATE"]].copy().reset_index(drop=True)

# %%
# step 4: merge the MNPASS_PAY_UPDATE values into the original dataframe
output_df = pd.merge(input_df, updated_acc_con_df, how="left", on=["A", "B"])
output_df["MNPASS_PAY"] = np.where(output_df["MNPASS_PAY_UPDATE"].isnull(), output_df["MNPASS_PAY"], output_df["MNPASS_PAY_UPDATE"])
output_df = output_df.drop(columns=["MNPASS_PAY_UPDATE"])
m_net.links_df = output_df.copy()

# %% [markdown]
# # Write model network as shapefile

# %%
#out_cols = ['model_link_id', 'id', 'assign_group', 'drive_access', 'roadway_class',
#            'lanes_AM', 'lanes_MD', 'lanes_PM', 'lanes_NT', 'segment_id', 'HOV', 
#            'price_sov_AM', 'geometry', 'managed']

roadway.write_roadway_as_shp(
    roadway_net = m_net,
    parameters = metcouncil_parameters,
    output_link_shp = os.path.join(output_dir2, 'fullnet_v04', 'shapefile', 'links_v04.shp'),
    output_node_shp = os.path.join(output_dir2, 'fullnet_v04', 'shapefile', 'nodes_v04.shp'),
    #link_output_variables = out_cols,
    data_to_csv = False,
    data_to_dbf = True,
    export_drive_only = False, # if user only wants drive links/nodes in the shapefile
)
# Out:
# 2024-12-13 23:18:44, INFO: Writing Network as Shapefile
# 2024-12-13 23:18:44, DEBUG: Output Variables:
#  - model_link_id
#  - link_id
#  - A
#  - B
#  - shstGeometryId
#  - shape_id
#  - distance
#  - roadway
#  - name
#  - roadway_class
#  - roadway_class_idx
#  - assign_group
#  - mpo
#  - AADT
#  - area_type
#  - county
#  - centroidconnect
#  - segment_id
#  - drive_access
#  - walk_access
#  - bike_access
#  - truck_access
#  - bus_only
#  - rail_only
#  - bike_facility
#  - bike
#  - walk
#  - MNPASS_CODE
#  - MNPASS_PAY
#  - managed
#  - mrcc_id
#  - ROUTE_SYS
#  - trn_priority_AM
#  - trn_priority_MD
#  - trn_priority_PM
#  - trn_priority_NT
#  - ttime_assert_AM
#  - ttime_assert_MD
#  - ttime_assert_PM
#  - ttime_assert_NT
#  - lanes_AM
#  - lanes_MD
#  - lanes_PM
#  - lanes_NT
#  - access_AM
#  - access_MD
#  - access_PM
#  - access_NT
#  - count_year
#  - count_AM
#  - count_MD
#  - count_PM
#  - count_NT
#  - count_daily
#  - ML_lanes_AM
#  - ML_lanes_MD
#  - ML_lanes_PM
#  - ML_lanes_NT
#  - N
#  - osm_node_id
#  - bike_node
#  - transit_node
#  - walk_node
#  - drive_node
#  - geometry
#  - X
#  - Y
# 2024-12-13 23:18:44, DEBUG: Network Link Variables:
#  - lanes
#  - egress
#  - managed
#  - model_link_id
#  - name
#  - access
#  - GP_B
#  - MNPASS_CODE
#  - rail_only
#  - projects
#  - bike_access
#  - ML_access_point
#  - roadway
#  - sc_lanes
#  - walk_access
#  - GP_A
#  - B
#  - source_geometry
#  - ML_egress_point
#  - A
#  - ref
#  - source_model_link_id
#  - drive_access
#  - distance
#  - bus_only
#  - shape_id
#  - price
#  - ML_projects
#  - osm_link_id
#  - locationReferences
#  - shstReferenceId
#  - shstGeometryId
#  - fromIntersectionId
#  - toIntersectionId
#  - u
#  - v
#  - nodeIds
#  - wayId
#  - roadClass
#  - oneWay
#  - roundabout
#  - link
#  - oneway
#  - lanes_osm
#  - highway
#  - service
#  - width
#  - maxspeed
#  - junction
#  - bridge
#  - tunnel
#  - landuse
#  - area
#  - key
#  - forward
#  - backReferenceId
#  - metadata
#  - source
#  - county
#  - length
#  - centroidconnect
#  - assign_group
#  - roadway_class
#  - trn_priority
#  - area_type
#  - ramp_flag
#  - bike
#  - walk
#  - MNPASS_PAY
#  - GP_model_link_id
#  - segment_id
#  - mpo
#  - AADT
#  - count_AM
#  - count_MD
#  - count_PM
#  - count_NT
#  - count_daily
#  - count_year
#  - trn_priority_EA
#  - trn_priority_AM
#  - trn_priority_MD
#  - trn_priority_PM
#  - trn_priority_NT
#  - ttime_assert_EA
#  - ttime_assert_AM
#  - ttime_assert_MD
#  - ttime_assert_PM
#  - ttime_assert_NT
#  - lanes_EA
#  - lanes_AM
#  - lanes_MD
#  - lanes_PM
#  - lanes_NT
#  - ML_lanes_EA
#  - ML_lanes_AM
#  - ML_lanes_MD
#  - ML_lanes_PM
#  - ML_lanes_NT
#  - price_sov_EA
#  - price_hov2_EA
#  - price_hov3_EA
#  - price_truck_EA
#  - price_sov_AM
#  - price_hov2_AM
#  - price_hov3_AM
#  - price_truck_AM
#  - price_sov_MD
#  - price_hov2_MD
#  - price_hov3_MD
#  - price_truck_MD
#  - price_sov_PM
#  - price_hov2_PM
#  - price_hov3_PM
#  - price_truck_PM
#  - price_sov_NT
#  - price_hov2_NT
#  - price_hov3_NT
#  - price_truck_NT
#  - access_EA
#  - access_AM
#  - access_MD
#  - access_PM
#  - access_NT
#  - geometry
# 2024-12-13 23:18:44, DEBUG: Network Node Variables:
#  - model_node_id
#  - X
#  - Y
#  - osm_node_id
#  - projects
#  - shst_node_id
#  - drive_access
#  - walk_access
#  - bike_access
#  - rail_only
#  - geometry
#  - GP_model_node_id
#  - county
#  - N
# 2024-12-13 23:18:44, INFO: Renaming DBF Node Variables
# 2024-12-13 23:18:44, INFO: Renaming variables so that they are DBF-safe
# 2024-12-13 23:18:44, DEBUG: Variable crosswalk: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler\examples\settings\net_to_dbf.csv
#                  net         dbf
# 0     model_link_id     link_id
# 1    shstGeometryId       geoId
# 2     roadway_class     rdclass
# 3     bike_facility    bike_fac
# 4       bike_access    bikeable
# 5    transit_access     transit
# 6       walk_access    walkable
# 7      drive_access    drivable
# 8      truck_access       truck
# 9   trn_priority_AM       tp_AM
# 10  trn_priority_MD       tp_MD
# 11  trn_priority_PM       tp_PM
# 12  trn_priority_NT       tp_NT
# 13  ttime_assert_AM      tta_AM
# 14  ttime_assert_MD      tta_MD
# 15  ttime_assert_PM      tta_PM
# 16  ttime_assert_NT      tta_NT
# 17     price_sov_AM    P_SOV_AM
# 18    price_hov2_AM   P_HOV2_AM
# 19    price_hov3_AM   P_HOV3_AM
# 20   price_truck_AM    P_TRK_AM
# 21     price_sov_MD    P_SOV_MD
# 22    price_hov2_MD   P_HOV2_MD
# 23    price_hov3_MD   P_HOV3_MD
# 24   price_truck_MD    P_TRK_MD
# 25     price_sov_PM    P_SOV_PM
# 26    price_hov2_PM   P_HOV2_PM
# 27    price_hov3_PM   P_HOV3_PM
# 28   price_truck_PM    P_TRK_PM
# 29     price_sov_NT    P_SOV_NT
# 30    price_hov2_NT   P_HOV2_NT
# 31    price_hov3_NT   P_HOV3_NT
# 32   price_truck_NT    P_TRK_NT
# 33   road_class_idx  rdclass_ix
# 34     assign_group    assgngrp
# 35  centroidconnect    centroid
# 36      count_daily   count_day
# 37    model_node_id     node_id
# 38      osm_node_id   osmnodeid
# 39     transit_node   tran_node
# 40      ML_lanes_AM  m_lanes_AM
# 41      ML_lanes_MD  m_lanes_MD
# 42      ML_lanes_PM  m_lanes_PM
# 43      ML_lanes_NT  m_lanes_NT
# 2024-12-13 23:18:50, DEBUG: DBF Variables: X,Y,osmnodeid,drivable,walkable,bikeable,rail_only,geometry,county,N
# 2024-12-13 23:18:50, INFO: Renaming DBF Link Variables
# 2024-12-13 23:18:50, INFO: Renaming variables so that they are DBF-safe
# 2024-12-13 23:18:50, DEBUG: Variable crosswalk: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler\examples\settings\net_to_dbf.csv
#                  net         dbf
# 0     model_link_id     link_id
# 1    shstGeometryId       geoId
# 2     roadway_class     rdclass
# 3     bike_facility    bike_fac
# 4       bike_access    bikeable
# 5    transit_access     transit
# 6       walk_access    walkable
# 7      drive_access    drivable
# 8      truck_access       truck
# 9   trn_priority_AM       tp_AM
# 10  trn_priority_MD       tp_MD
# 11  trn_priority_PM       tp_PM
# 12  trn_priority_NT       tp_NT
# 13  ttime_assert_AM      tta_AM
# 14  ttime_assert_MD      tta_MD
# 15  ttime_assert_PM      tta_PM
# 16  ttime_assert_NT      tta_NT
# 17     price_sov_AM    P_SOV_AM
# 18    price_hov2_AM   P_HOV2_AM
# 19    price_hov3_AM   P_HOV3_AM
# 20   price_truck_AM    P_TRK_AM
# 21     price_sov_MD    P_SOV_MD
# 22    price_hov2_MD   P_HOV2_MD
# 23    price_hov3_MD   P_HOV3_MD
# 24   price_truck_MD    P_TRK_MD
# 25     price_sov_PM    P_SOV_PM
# 26    price_hov2_PM   P_HOV2_PM
# 27    price_hov3_PM   P_HOV3_PM
# 28   price_truck_PM    P_TRK_PM
# 29     price_sov_NT    P_SOV_NT
# 30    price_hov2_NT   P_HOV2_NT
# 31    price_hov3_NT   P_HOV3_NT
# 32   price_truck_NT    P_TRK_NT
# 33   road_class_idx  rdclass_ix
# 34     assign_group    assgngrp
# 35  centroidconnect    centroid
# 36      count_daily   count_day
# 37    model_node_id     node_id
# 38      osm_node_id   osmnodeid
# 39     transit_node   tran_node
# 40      ML_lanes_AM  m_lanes_AM
# 41      ML_lanes_MD  m_lanes_MD
# 42      ML_lanes_PM  m_lanes_PM
# 43      ML_lanes_NT  m_lanes_NT
# 2024-12-13 23:18:51, DEBUG: DBF Variables: managed,link_id,name,MNPASS_CODE,rail_only,bikeable,roadway,walkable,B,A,drivable,distance,bus_only,shape_id,geoId,county,centroid,assgngrp,rdclass,area_type,bike,walk,MNPASS_PAY,segment_id,mpo,AADT,count_AM,count_MD,count_PM,count_NT,count_day,count_year,tp_AM,tp_MD,tp_PM,tp_NT,tta_AM,tta_MD,tta_PM,tta_NT,lanes_AM,lanes_MD,lanes_PM,lanes_NT,m_lanes_AM,m_lanes_MD,m_lanes_PM,m_lanes_NT,access_AM,access_MD,access_PM,access_NT,geometry
# 2024-12-13 23:18:51, INFO: Writing Node Shapes:
#  - Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\output\fullnet_v04\shapefile\nodes_v04.shp
# 2024-12-13 23:19:01, INFO: Writing Link Shapes:
#  - Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\output\fullnet_v04\shapefile\links_v04.shp
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\roadway.py:876: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   links_dbf_df.to_file(output_link_shp)
# c:\Users\USYS671257\.conda\envs\wrangler\lib\site-packages\pyogrio\raw.py:723: RuntimeWarning: Normalized/laundered field name: 'MNPASS_CODE' to 'MNPASS_COD'
#   ogr_write(

# %% [markdown]
# # Write model network for Cube

# %%
roadway.write_roadway_as_fixedwidth(
    roadway_net = m_net,
    parameters = metcouncil_parameters,
    zones = metcouncil_parameters.zones,
    output_link_txt = os.path.join(output_dir2, 'fullnet_v04', 'links.txt'),
    output_node_txt = os.path.join(output_dir2,  'fullnet_v04','nodes.txt'),
    output_link_header_width_txt = os.path.join(output_dir2,  'fullnet_v04', 'links_header_width.txt'),
    output_node_header_width_txt = os.path.join(output_dir2,  'fullnet_v04','nodes_header_width.txt'),
    output_cube_network_script = os.path.join(output_dir2,  'fullnet_v04',  'make_complete_network_from_fixed_width_file.s'),
)
# Out:
# 2024-12-13 23:20:14, DEBUG: Network Link Variables:
#  - lanes
#  - egress
#  - managed
#  - model_link_id
#  - name
#  - access
#  - GP_B
#  - MNPASS_CODE
#  - rail_only
#  - projects
#  - bike_access
#  - ML_access_point
#  - roadway
#  - sc_lanes
#  - walk_access
#  - GP_A
#  - B
#  - source_geometry
#  - ML_egress_point
#  - A
#  - ref
#  - source_model_link_id
#  - drive_access
#  - distance
#  - bus_only
#  - shape_id
#  - price
#  - ML_projects
#  - osm_link_id
#  - locationReferences
#  - shstReferenceId
#  - shstGeometryId
#  - fromIntersectionId
#  - toIntersectionId
#  - u
#  - v
#  - nodeIds
#  - wayId
#  - roadClass
#  - oneWay
#  - roundabout
#  - link
#  - oneway
#  - lanes_osm
#  - highway
#  - service
#  - width
#  - maxspeed
#  - junction
#  - bridge
#  - tunnel
#  - landuse
#  - area
#  - key
#  - forward
#  - backReferenceId
#  - metadata
#  - source
#  - county
#  - length
#  - centroidconnect
#  - assign_group
#  - roadway_class
#  - trn_priority
#  - area_type
#  - ramp_flag
#  - bike
#  - walk
#  - MNPASS_PAY
#  - GP_model_link_id
#  - segment_id
#  - mpo
#  - AADT
#  - count_AM
#  - count_MD
#  - count_PM
#  - count_NT
#  - count_daily
#  - count_year
#  - trn_priority_EA
#  - trn_priority_AM
#  - trn_priority_MD
#  - trn_priority_PM
#  - trn_priority_NT
#  - ttime_assert_EA
#  - ttime_assert_AM
#  - ttime_assert_MD
#  - ttime_assert_PM
#  - ttime_assert_NT
#  - lanes_EA
#  - lanes_AM
#  - lanes_MD
#  - lanes_PM
#  - lanes_NT
#  - ML_lanes_EA
#  - ML_lanes_AM
#  - ML_lanes_MD
#  - ML_lanes_PM
#  - ML_lanes_NT
#  - price_sov_EA
#  - price_hov2_EA
#  - price_hov3_EA
#  - price_truck_EA
#  - price_sov_AM
#  - price_hov2_AM
#  - price_hov3_AM
#  - price_truck_AM
#  - price_sov_MD
#  - price_hov2_MD
#  - price_hov3_MD
#  - price_truck_MD
#  - price_sov_PM
#  - price_hov2_PM
#  - price_hov3_PM
#  - price_truck_PM
#  - price_sov_NT
#  - price_hov2_NT
#  - price_hov3_NT
#  - price_truck_NT
#  - access_EA
#  - access_AM
#  - access_MD
#  - access_PM
#  - access_NT
#  - geometry
# 2024-12-13 23:20:14, DEBUG: Network Node Variables:
#  - model_node_id
#  - X
#  - Y
#  - osm_node_id
#  - projects
#  - shst_node_id
#  - drive_access
#  - walk_access
#  - bike_access
#  - rail_only
#  - geometry
#  - GP_model_node_id
#  - county
#  - N
# 2024-12-13 23:20:14, INFO: Starting fixed width conversion
# 2024-12-13 23:31:13, INFO: Writing out link database
# 2024-12-13 23:32:02, INFO: Writing out link header and width ----
# 2024-12-13 23:32:02, INFO: Starting fixed width conversion
# 2024-12-13 23:32:41, INFO: Writing out node database
# 2024-12-13 23:32:44, INFO: Writing out node header and width

# %%
version_04_scenario.transit_net.road_net = version_04_scenario.road_net
standard_transit_net = StandardTransit.fromTransitNetwork(version_04_scenario.transit_net, parameters=metcouncil_parameters)

# %%
standard_transit_net = metcouncil_transit.transit_standard_to_met_council_transit_network(
    transit_net = standard_transit_net,
    parameters = metcouncil_parameters,
    line_name_xwalk = os.path.join(output_dir2, 'fullnet_v04', 'line_name_xwalk.csv')
)
# Out:
# 2024-12-13 23:32:55, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 23:32:55, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler
# No missing values found in column 'agency_raw_name'.
# No missing values found in column 'agency_raw_name'.
# No missing values found in column 'agency_raw_name'.
# No missing values found in column 'agency_raw_name'.
# No missing values found in column 'agency_raw_name'.
# 2024-12-13 23:32:56, INFO: Converting GTFS Standard Properties to MetCouncil's Cube Standard
# 2024-12-13 23:32:56, INFO: cube_wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\cube_wrangler
# 2024-12-13 23:32:56, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\Yue_temp\metcouncil\met_council_wrangler
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\met_council_wrangler\met_council_wrangler\metcouncil_transit.py:1308: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   trip_df.groupby(["agency_id", "route_id", "direction_id", "shp_index"])
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\met_council_wrangler\met_council_wrangler\metcouncil_transit.py:1320: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   trip_df.groupby(["agency_id", "route_id", "direction_id", "shp_index"])
# 2024-12-13 23:32:57, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:32:58, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:32:58, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:32:59, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:32:59, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:00, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:00, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:00, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:01, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:01, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:03, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:03, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:04, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:04, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:06, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:07, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:07, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:08, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:08, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:10, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:10, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:11, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:11, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:12, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:12, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:14, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:14, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:15, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:15, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:16, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:16, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:18, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:18, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:19, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:19, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:20, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:20, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:21, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:21, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:22, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:22, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:23, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:23, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:25, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:25, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:26, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:26, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:27, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:27, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:28, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:28, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:29, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:29, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:30, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:30, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:30, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:31, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:31, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:32, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:32, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:33, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:33, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:34, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:34, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:35, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:35, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:36, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:36, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:37, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:37, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:38, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:38, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:39, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:39, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:40, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:40, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:42, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:42, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:42, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:43, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:43, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:44, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:44, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:45, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:45, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:46, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:46, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:47, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:47, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:47, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:48, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:48, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:49, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:49, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:50, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:50, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:52, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:52, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:53, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:53, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:54, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:54, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:55, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:55, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:56, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:56, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:57, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:57, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:57, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:58, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:58, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:59, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:33:59, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:00, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:00, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:01, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:01, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:03, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:03, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:04, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:04, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:06, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:06, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:07, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:07, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:08, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:08, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:10, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:10, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:11, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:11, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:11, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:12, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:12, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:14, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:14, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:15, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:15, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:16, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:16, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:16, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:18, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:18, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:19, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:19, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:20, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:20, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:20, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:21, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:21, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:22, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:22, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:23, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:23, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:25, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:25, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:26, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:26, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:27, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:27, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:28, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:28, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:28, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:29, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:29, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:30, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:30, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:31, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:31, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:32, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:32, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:33, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:33, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:34, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:34, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:35, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:35, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:35, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:36, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:37, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:37, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:38, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:38, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:39, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:39, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:40, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:40, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:42, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:42, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:43, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:43, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:44, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:44, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:45, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:45, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:46, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:46, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:47, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:47, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:48, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:48, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:49, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:49, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:50, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:50, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:50, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:52, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:52, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:53, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:53, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:54, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:54, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:55, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:55, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:56, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:56, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:57, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:57, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:58, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:58, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:58, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:59, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:34:59, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:00, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:00, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:01, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:01, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:01, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:03, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:03, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:04, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:04, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:06, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:06, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:07, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:07, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:08, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:08, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:10, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:10, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:11, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:11, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:12, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:12, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:14, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:14, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:15, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:15, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:15, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:16, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:16, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:18, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:18, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:18, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:19, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:19, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:20, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:20, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:21, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:21, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:22, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:22, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:23, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:23, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:25, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:25, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:26, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:26, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:27, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:27, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:28, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:28, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:29, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:29, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:30, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:30, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:31, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:31, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:31, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:32, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:32, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:33, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:33, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:34, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:34, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:35, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:35, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:36, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:36, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:37, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:37, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:38, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:38, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:39, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:39, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:40, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:40, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:40, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:42, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:42, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:43, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:43, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:44, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:44, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:45, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:45, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:46, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:46, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:46, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:47, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:47, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:48, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:48, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:49, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:49, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:50, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:50, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:52, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:53, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:53, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:53, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:54, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:54, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:55, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:55, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:56, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:56, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:57, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:57, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:58, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:58, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:59, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:35:59, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:00, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:00, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:01, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:01, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:02, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:03, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:03, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:04, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:04, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:05, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:06, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:06, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:07, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:07, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:08, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:08, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:09, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:10, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:10, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:11, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:11, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:12, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:12, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:13, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:14, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:14, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:15, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:16, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:16, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:17, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:18, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:18, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:19, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:19, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:19, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:20, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:20, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:21, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:21, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:22, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:22, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:23, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:23, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:24, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:25, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:25, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:26, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:26, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:27, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:27, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:27, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:28, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:28, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:29, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:29, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:30, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:31, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:32, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:32, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:33, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:33, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:34, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:34, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:35, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:35, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:36, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:36, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:37, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:37, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:38, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:38, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:39, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:39, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:40, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:41, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:42, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:42, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:43, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:43, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:44, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:44, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:45, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:45, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:46, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:46, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:47, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:47, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:48, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:48, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:49, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:49, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:50, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:50, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:51, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:52, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:52, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:53, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:53, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:54, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:54, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:55, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:55, DEBUG: Validating + coercing value to shapes
# 2024-12-13 23:36:56, DEBUG: Validating + coercing value to trip_cube_df

# %%
standard_transit_net.write_as_cube_lin(outpath = os.path.join(output_dir2, 'fullnet_v04', 'transit.lin'))
