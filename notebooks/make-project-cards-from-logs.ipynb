# %% [markdown]
# # Make Project Cards from Log Files

# %%
import os
import sys
from pathlib import Path

from met_council_wrangler import CubeTransit
from met_council_wrangler import MetCouncil_Parameters
from cube_wrangler import Parameters
from cube_wrangler import Project

import network_wrangler
from network_wrangler import load_roadway

# %%
network_wrangler.setup_logging()

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Remote I/O & Parameters

# %%
root_dir = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\make_project_card_from_logs")

card_dir = os.path.join(root_dir, 'project_cards')
network_dir = os.path.join(root_dir, 'network_standard')
log_file_dir = os.path.join(root_dir, 'log_files')

metcouncil_wrangler_dir = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\software\met_council_wrangler")
cube_wrangler_dir = os.path.join(r"Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\software\cube_wrangler")

# %%
metcouncil_parameters = MetCouncil_Parameters(
    metcouncil_wrangler_base_dir=metcouncil_wrangler_dir,
    cube_wrangler_base_dir=cube_wrangler_dir
)
# Out:
# 2024-10-29 22:57:12, INFO: cube_wrangler base directory set as: Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\software\cube_wrangler
# 2024-10-29 22:57:12, INFO: MetCouncil Wrangler base directory set as: Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\software\met_council_wrangler

# %% [markdown]
# ## Data Reads

# %%
link_file = os.path.join(network_dir, 'links.json')
node_file = os.path.join(network_dir, 'nodes.geojson')
shape_file = os.path.join(network_dir, 'shapes.geojson')

roadway_net = load_roadway(
    links_file=link_file,
    nodes_file=node_file,
    shapes_file=shape_file,
)
# Out:
# 2024-10-29 22:57:12, DEBUG: Reading nodes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\make_project_card_from_logs\network_standard\nodes.geojson.
# 2024-10-29 22:57:12, DEBUG: Estimated read time: 4 seconds.
# 2024-10-29 22:57:32, DEBUG: Read 414282 nodes from file in 20.06.
# 2024-10-29 22:57:32, DEBUG: Turning node data into official nodes_df
# 2024-10-29 22:57:39, INFO: Read 414282 nodes from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\make_project_card_from_logs\network_standard\nodes.geojson in 26.92.
# 2024-10-29 22:57:40, INFO: Reading links from Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\make_project_card_from_logs\network_standard\links.json.
# 2024-10-29 22:57:40, DEBUG: Estimated read time: 3 minutes.
# 2024-10-29 22:58:39, DEBUG: Read 1061756 links in 59.05.
# 2024-10-29 22:58:39, DEBUG: Creating 1061756 links.
# 2024-10-29 23:00:09, DEBUG: 1061756 new links.
# 2024-10-29 23:00:09, INFO: Read + transformed 1061756 links from             Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\make_project_card_from_logs\network_standard\links.json in 149.12.

# %% [markdown]
# ## Make a Project Card

# %%
log_file_name = os.path.join(log_file_dir, 'testedit_1.log')
card_file_name = Path(os.path.join(card_dir, os.path.split(os.path.splitext(log_file_name)[0]+'.yml')[1]))
card_file_name
# Out:
# WindowsPath('Z:/Met_Council/31000743A/Task 1 Consolidate Architecture/consolidate_architecture/make_project_card_from_logs/project_cards/testedit_1.yml')

# %%
project = Project.create_project(
    base_roadway_network = roadway_net,
    roadway_log_file = log_file_name,
    parameters = metcouncil_parameters,
)
# Out:
# 2024-10-29 23:00:19, INFO: No base transit network.
# 2024-10-29 23:00:19, INFO: No transit changes given or processed.
# 2024-10-29 23:00:19, INFO: No Project Name - Using name of log file
# 2024-10-29 23:00:19, INFO: Reading logfile: Z:\Met_Council\31000743A\Task 1 Consolidate Architecture\consolidate_architecture\make_project_card_from_logs\log_files\testedit_1.log
# 2024-10-29 23:00:19, DEBUG: node lines: ['Node,N,OSM_NODE_ID[12],DRIVE_ACCESS,WALK_ACCESS,BIKE_ACCESS,RAIL_ONLY,X,Y,DRIVE_NODE,COUNTY']
# 2024-10-29 23:00:19, DEBUG: link lines: ['Link,A,B,SHSTGEOMETRYID[32],NAME[93],ROADWAY[14],DRIVE_ACCESS,WALK_ACCESS,BIKE_ACCESS,COUNTY,MODEL_LINK_ID,RAIL_ONLY,BUS_ONLY,CENTROIDCONNECT,ASSIGN_GROUP,ROADWAY_CLASS,AREA_TYPE,BIKE,WALK,MNPASS_CODE,MNPASS_PAY,MANAGED,DISTANCE,MPO,AADT,COUNT_YEAR,SEGMENT_ID,LANES_AM', 'L,C,0,174276,322631,"590f3995c22d840b9c0a950c2fa41fb5","Norling Avenue Southwest","residential",1,1,1,22,428593,0,0,0,50,50,1,3,3,0,0,0,0.9493,0,0,2017,0,4', 'L,C,0,322631,174276,"590f3995c22d840b9c0a950c2fa41fb5","Norling Avenue Southwest","residential",1,1,1,22,719450,0,0,0,50,50,1,3,3,0,0,0,0.9493,0,0,2017,0,4', 'L,C,1,172456,174276,"b76193076c02e2c484cc3ef57e2b34bf","Norling Avenue Southwest","residential",1,1,1,22,271161,0,0,0,50,50,1,3,3,0,0,0,0.9998,0,0,2017,0,4', 'L,C,1,174276,172456,"b76193076c02e2c484cc3ef57e2b34bf","Norling Avenue Southwest","residential",1,1,1,22,1052565,0,0,0,50,50,1,3,3,0,0,0,0.9998,0,0,2017,0,4', 'L,C,2,167648,172456,"214652bc9ccb41d4f0392d5afef2470c","Norling Avenue Southwest","residential",1,1,1,22,263379,0,0,0,50,50,1,3,3,0,0,0,1.0169,0,0,2017,0,4', 'L,C,2,172456,167648,"214652bc9ccb41d4f0392d5afef2470c","Norling Avenue Southwest","residential",1,1,1,22,712909,0,0,0,50,50,1,3,3,0,0,0,1.0169,0,0,2017,0,4']
# 2024-10-29 23:00:19, DEBUG: Node Cols: ['OBJECT', 'OPERATION', 'GROUP', 'N', 'OSM_NODE_ID[12]', 'DRIVE_ACCESS', 'WALK_ACCESS', 'BIKE_ACCESS', 'RAIL_ONLY', 'X', 'Y', 'DRIVE_NODE', 'COUNTY']
# 2024-10-29 23:00:19, DEBUG: Link Cols: ['OBJECT', 'OPERATION', 'GROUP', 'A', 'B', 'SHSTGEOMETRYID[32]', 'NAME[93]', 'ROADWAY[14]', 'DRIVE_ACCESS', 'WALK_ACCESS', 'BIKE_ACCESS', 'COUNTY', 'MODEL_LINK_ID', 'RAIL_ONLY', 'BUS_ONLY', 'CENTROIDCONNECT', 'ASSIGN_GROUP', 'ROADWAY_CLASS', 'AREA_TYPE', 'BIKE', 'WALK', 'MNPASS_CODE', 'MNPASS_PAY', 'MANAGED', 'DISTANCE', 'MPO', 'AADT', 'COUNT_YEAR', 'SEGMENT_ID', 'LANES_AM']
# 2024-10-29 23:00:20, DEBUG: Node DF: Empty DataFrame
# Columns: [OBJECT, OPERATION, GROUP, N, OSM_NODE_ID[12], DRIVE_ACCESS, WALK_ACCESS, BIKE_ACCESS, RAIL_ONLY, X, Y, DRIVE_NODE, COUNTY]
# Index: []
# 2024-10-29 23:00:20, DEBUG: Link DF:   OBJECT OPERATION GROUP       A       B                SHSTGEOMETRYID[32]  \
# 0      L         C     0  174276  322631  590f3995c22d840b9c0a950c2fa41fb5
# 1      L         C     0  322631  174276  590f3995c22d840b9c0a950c2fa41fb5
# 2      L         C     1  172456  174276  b76193076c02e2c484cc3ef57e2b34bf
# 3      L         C     1  174276  172456  b76193076c02e2c484cc3ef57e2b34bf
# 4      L         C     2  167648  172456  214652bc9ccb41d4f0392d5afef2470c
# 5      L         C     2  172456  167648  214652bc9ccb41d4f0392d5afef2470c
#
#                    NAME[93]  ROADWAY[14] DRIVE_ACCESS WALK_ACCESS  ... WALK  \
# 0  Norling Avenue Southwest  residential            1           1  ...    3
# 1  Norling Avenue Southwest  residential            1           1  ...    3
# 2  Norling Avenue Southwest  residential            1           1  ...    3
# 3  Norling Avenue Southwest  residential            1           1  ...    3
# 4  Norling Avenue Southwest  residential            1           1  ...    3
# 5  Norling Avenue Southwest  residential            1           1  ...    3
#
#   MNPASS_CODE MNPASS_PAY MANAGED DISTANCE MPO AADT COUNT_YEAR SEGMENT_ID  \
# 0           0          0       0   0.9493   0    0       2017          0
# 1           0          0       0   0.9493   0    0       2017          0
# 2           0          0       0   0.9998   0    0       2017          0
# 3           0          0       0   0.9998   0    0       2017          0
# 4           0          0       0   1.0169   0    0       2017          0
# 5           0          0       0   1.0169   0    0       2017          0
#
#   LANES_AM
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# 5        4
#
# [6 rows x 30 columns]
# 2024-10-29 23:00:20, INFO: Processed 0 Node lines and 6 Link lines
# 2024-10-29 23:00:33, DEBUG: No scoped values trn_priority. Returning default.
# 2024-10-29 23:00:46, DEBUG: No scoped values trn_priority. Returning default.
# 2024-10-29 23:00:59, DEBUG: No scoped values trn_priority. Returning default.
# 2024-10-29 23:01:14, DEBUG: No scoped values trn_priority. Returning default.
# 2024-10-29 23:01:34, DEBUG: No scoped values trn_priority. Returning default.
# 2024-10-29 23:01:34, WARNING: Specified variable to split: ttime_assert not in network variables: Index(['shstReferenceId', 'shape_id', 'shstGeometryId', 'fromIntersectionId',
#        'toIntersectionId', 'u', 'v', 'nodeIds', 'wayId', 'roadClass', 'oneWay',
#        'roundabout', 'link', 'oneway', 'ref', 'name', 'highway', 'service',
#        'width', 'maxspeed', 'access', 'junction', 'bridge', 'tunnel',
#        'landuse', 'area', 'key', 'forward', 'backReferenceId', 'metadata',
#        'source', 'roadway', 'drive_access', 'walk_access', 'bike_access',
#        'county', 'length', 'A', 'B', 'model_link_id', 'locationReferences',
#        'rail_only', 'bus_only', 'centroidconnect', 'lanes', 'assign_group',
#        'roadway_class', 'trn_priority', 'area_type', 'ramp_flag', 'bike',
#        'walk', 'MNPASS_CODE', 'MNPASS_PAY', 'managed', 'geometry', 'distance',
#        'projects', 'price', 'ML_projects', 'osm_link_id', 'trn_priority_EA',
#        'trn_priority_AM', 'trn_priority_MD', 'trn_priority_PM',
#        'trn_priority_NT'],
#       dtype='object'). Returning 0.
# 2024-10-29 23:02:08, DEBUG: No scoped values lanes. Returning default.
# 2024-10-29 23:02:41, DEBUG: No scoped values lanes. Returning default.
# 2024-10-29 23:03:04, DEBUG: No scoped values lanes. Returning default.
# 2024-10-29 23:03:18, DEBUG: No scoped values lanes. Returning default.
# 2024-10-29 23:03:31, DEBUG: No scoped values lanes. Returning default.
# 2024-10-29 23:03:31, WARNING: Specified variable to split: ML_lanes not in network variables: Index(['shstReferenceId', 'shape_id', 'shstGeometryId', 'fromIntersectionId',
#        'toIntersectionId', 'u', 'v', 'nodeIds', 'wayId', 'roadClass', 'oneWay',
#        'roundabout', 'link', 'oneway', 'ref', 'name', 'highway', 'service',
#        'width', 'maxspeed', 'access', 'junction', 'bridge', 'tunnel',
#        'landuse', 'area', 'key', 'forward', 'backReferenceId', 'metadata',
#        'source', 'roadway', 'drive_access', 'walk_access', 'bike_access',
#        'county', 'length', 'A', 'B', 'model_link_id', 'locationReferences',
#        'rail_only', 'bus_only', 'centroidconnect', 'lanes', 'assign_group',
#        'roadway_class', 'trn_priority', 'area_type', 'ramp_flag', 'bike',
#        'walk', 'MNPASS_CODE', 'MNPASS_PAY', 'managed', 'geometry', 'distance',
#        'projects', 'price', 'ML_projects', 'osm_link_id', 'trn_priority_EA',
#        'trn_priority_AM', 'trn_priority_MD', 'trn_priority_PM',
#        'trn_priority_NT', 'ttime_assert_EA', 'ttime_assert_AM',
#        'ttime_assert_MD', 'ttime_assert_PM', 'ttime_assert_NT', 'lanes_EA',
#        'lanes_AM', 'lanes_MD', 'lanes_PM', 'lanes_NT'],
#       dtype='object'). Returning 0.
# 2024-10-29 23:03:44, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:03:57, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:04:11, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:04:25, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:04:38, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:04:52, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:05:06, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:05:19, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:05:33, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:05:46, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:06:00, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:06:13, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:06:27, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:06:41, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:06:54, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:07:07, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:07:21, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:07:35, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:07:48, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:08:02, DEBUG: No scoped values price. Returning default.
# 2024-10-29 23:08:16, DEBUG: No scoped values access. Returning default.
# 2024-10-29 23:08:29, DEBUG: No scoped values access. Returning default.
# 2024-10-29 23:08:43, DEBUG: No scoped values access. Returning default.
# 2024-10-29 23:08:57, DEBUG: No scoped values access. Returning default.
# 2024-10-29 23:09:11, DEBUG: No scoped values access. Returning default.
# 2024-10-29 23:09:11, INFO: Evaluating compatibility between roadway network changes and base network. Not evaluating deletions.
# 2024-10-29 23:09:13, INFO: Evaluating project changes.
# 2024-10-29 23:09:13, DEBUG: Processing link deletions
# 2024-10-29 23:09:13, DEBUG: No link deletions processed
# 2024-10-29 23:09:13, DEBUG: Processing link additions
# 2024-10-29 23:09:13, DEBUG: No link additions processed
# 2024-10-29 23:09:13, DEBUG: Processing changes
# 2024-10-29 23:09:13, DEBUG:         A       B                    shstGeometryId                      name  \
# 0  174276  322631  590f3995c22d840b9c0a950c2fa41fb5  Norling Avenue Southwest
# 1  322631  174276  590f3995c22d840b9c0a950c2fa41fb5  Norling Avenue Southwest
# 2  172456  174276  b76193076c02e2c484cc3ef57e2b34bf  Norling Avenue Southwest
# 3  174276  172456  b76193076c02e2c484cc3ef57e2b34bf  Norling Avenue Southwest
# 4  167648  172456  214652bc9ccb41d4f0392d5afef2470c  Norling Avenue Southwest
# 5  172456  167648  214652bc9ccb41d4f0392d5afef2470c  Norling Avenue Southwest
#
#        roadway  drive_access  walk_access  bike_access county  model_link_id  \
# 0  residential          True         True         True     22         428593
# 1  residential          True         True         True     22         719450
# 2  residential          True         True         True     22         271161
# 3  residential          True         True         True     22        1052565
# 4  residential          True         True         True     22         263379
# 5  residential          True         True         True     22         712909
#
#    ...  roadway_class  area_type  bike  walk  MNPASS_CODE MNPASS_PAY  managed  \
# 0  ...           50.0          1     3     3            0          0        0
# 1  ...           50.0          1     3     3            0          0        0
# 2  ...           50.0          1     3     3            0          0        0
# 3  ...           50.0          1     3     3            0          0        0
# 4  ...           50.0          1     3     3            0          0        0
# 5  ...           50.0          1     3     3            0          0        0
#
#    distance lanes_AM OPERATION_final
# 0    0.9493        4               C
# 1    0.9493        4               C
# 2    0.9998        4               C
# 3    0.9998        4               C
# 4    1.0169        4               C
# 5    1.0169        4               C
#
# [6 rows x 24 columns]
# 2024-10-29 23:09:13, WARNING: The following attributes are specified in the changes but do not exist in the base network: ['OPERATION_final']
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\project.py:1054: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.base_roadway_network.links_df[c].fillna("", inplace=True)
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\project.py:1058: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.base_roadway_network.links_df[c].fillna(0, inplace=True)
# \\dcclda00dat02.corp.pbwan.net\sag\projects\met_council\31000743a\task 1 consolidate architecture\software\cube_wrangler\cube_wrangler\project.py:1056: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.base_roadway_network.links_df[c].fillna(False, inplace=True)
# 2024-10-29 23:09:14, DEBUG: Assessing Column: shstGeometryId
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike
# 2024-10-29 23:09:14, DEBUG: Assessing Column: distance
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_CODE
# 2024-10-29 23:09:14, DEBUG: Assessing Column: managed
# 2024-10-29 23:09:14, DEBUG: Assessing Column: assign_group
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk
# 2024-10-29 23:09:14, DEBUG: Assessing Column: drive_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: rail_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: name
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway
# 2024-10-29 23:09:14, DEBUG: Assessing Column: A
# 2024-10-29 23:09:14, DEBUG: Assessing Column: B
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway_class
# 2024-10-29 23:09:14, DEBUG: Assessing Column: lanes_AM
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bus_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_PAY
# 2024-10-29 23:09:14, DEBUG: Properties with changes that will be processed: ['rail_only', 'lanes_AM', 'bus_only']
# 2024-10-29 23:09:14, DEBUG: Assessing Column: shstGeometryId
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike
# 2024-10-29 23:09:14, DEBUG: Assessing Column: distance
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_CODE
# 2024-10-29 23:09:14, DEBUG: Assessing Column: managed
# 2024-10-29 23:09:14, DEBUG: Assessing Column: assign_group
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk
# 2024-10-29 23:09:14, DEBUG: Assessing Column: drive_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: rail_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: name
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway
# 2024-10-29 23:09:14, DEBUG: Assessing Column: A
# 2024-10-29 23:09:14, DEBUG: Assessing Column: B
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway_class
# 2024-10-29 23:09:14, DEBUG: Assessing Column: lanes_AM
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bus_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_PAY
# 2024-10-29 23:09:14, DEBUG: Properties with changes that will be processed: ['rail_only', 'lanes_AM', 'bus_only']
# 2024-10-29 23:09:14, DEBUG: Assessing Column: shstGeometryId
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike
# 2024-10-29 23:09:14, DEBUG: Assessing Column: distance
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_CODE
# 2024-10-29 23:09:14, DEBUG: Assessing Column: managed
# 2024-10-29 23:09:14, DEBUG: Assessing Column: assign_group
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk
# 2024-10-29 23:09:14, DEBUG: Assessing Column: drive_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: rail_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: name
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway
# 2024-10-29 23:09:14, DEBUG: Assessing Column: A
# 2024-10-29 23:09:14, DEBUG: Assessing Column: B
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway_class
# 2024-10-29 23:09:14, DEBUG: Assessing Column: lanes_AM
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bus_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_PAY
# 2024-10-29 23:09:14, DEBUG: Properties with changes that will be processed: ['rail_only', 'lanes_AM', 'bus_only']
# 2024-10-29 23:09:14, DEBUG: Assessing Column: shstGeometryId
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike
# 2024-10-29 23:09:14, DEBUG: Assessing Column: distance
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_CODE
# 2024-10-29 23:09:14, DEBUG: Assessing Column: managed
# 2024-10-29 23:09:14, DEBUG: Assessing Column: assign_group
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk
# 2024-10-29 23:09:14, DEBUG: Assessing Column: drive_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: rail_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: name
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway
# 2024-10-29 23:09:14, DEBUG: Assessing Column: A
# 2024-10-29 23:09:14, DEBUG: Assessing Column: B
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway_class
# 2024-10-29 23:09:14, DEBUG: Assessing Column: lanes_AM
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bus_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_PAY
# 2024-10-29 23:09:14, DEBUG: Properties with changes that will be processed: ['rail_only', 'lanes_AM', 'bus_only']
# 2024-10-29 23:09:14, DEBUG: Assessing Column: shstGeometryId
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike
# 2024-10-29 23:09:14, DEBUG: Assessing Column: distance
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_CODE
# 2024-10-29 23:09:14, DEBUG: Assessing Column: managed
# 2024-10-29 23:09:14, DEBUG: Assessing Column: assign_group
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk
# 2024-10-29 23:09:14, DEBUG: Assessing Column: drive_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: rail_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: name
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway
# 2024-10-29 23:09:14, DEBUG: Assessing Column: A
# 2024-10-29 23:09:14, DEBUG: Assessing Column: B
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway_class
# 2024-10-29 23:09:14, DEBUG: Assessing Column: lanes_AM
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bus_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_PAY
# 2024-10-29 23:09:14, DEBUG: Properties with changes that will be processed: ['rail_only', 'lanes_AM', 'bus_only']
# 2024-10-29 23:09:14, DEBUG: Assessing Column: shstGeometryId
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike
# 2024-10-29 23:09:14, DEBUG: Assessing Column: distance
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_CODE
# 2024-10-29 23:09:14, DEBUG: Assessing Column: managed
# 2024-10-29 23:09:14, DEBUG: Assessing Column: assign_group
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk
# 2024-10-29 23:09:14, DEBUG: Assessing Column: drive_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: rail_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: name
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway
# 2024-10-29 23:09:14, DEBUG: Assessing Column: A
# 2024-10-29 23:09:14, DEBUG: Assessing Column: B
# 2024-10-29 23:09:14, DEBUG: Assessing Column: roadway_class
# 2024-10-29 23:09:14, DEBUG: Assessing Column: lanes_AM
# 2024-10-29 23:09:14, DEBUG: Assessing Column: walk_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bus_only
# 2024-10-29 23:09:14, DEBUG: Assessing Column: bike_access
# 2024-10-29 23:09:14, DEBUG: Assessing Column: MNPASS_PAY
# 2024-10-29 23:09:14, DEBUG: Properties with changes that will be processed: ['rail_only', 'lanes_AM', 'bus_only']
# 2024-10-29 23:09:14, DEBUG: 1 Changes Processed

# %%
project.roadway_changes[0:10]
# Out:
#   OBJECT OPERATION GROUP       A       B                    shstGeometryId  \
# 0      L         C     0  174276  322631  590f3995c22d840b9c0a950c2fa41fb5
# 1      L         C     0  322631  174276  590f3995c22d840b9c0a950c2fa41fb5
# 2      L         C     1  172456  174276  b76193076c02e2c484cc3ef57e2b34bf
# 3      L         C     1  174276  172456  b76193076c02e2c484cc3ef57e2b34bf
# 4      L         C     2  167648  172456  214652bc9ccb41d4f0392d5afef2470c
# 5      L         C     2  172456  167648  214652bc9ccb41d4f0392d5afef2470c
#
#                        name      roadway drive_access walk_access  ... mpo  \
# 0  Norling Avenue Southwest  residential            1           1  ...   0
# 1  Norling Avenue Southwest  residential            1           1  ...   0
# 2  Norling Avenue Southwest  residential            1           1  ...   0
# 3  Norling Avenue Southwest  residential            1           1  ...   0
# 4  Norling Avenue Southwest  residential            1           1  ...   0
# 5  Norling Avenue Southwest  residential            1           1  ...   0
#
#   AADT count_year segment_id lanes_AM model_node_id osm_node_id    X    Y  \
# 0    0       2017          0        4           NaN         NaN  NaN  NaN
# 1    0       2017          0        4           NaN         NaN  NaN  NaN
# 2    0       2017          0        4           NaN         NaN  NaN  NaN
# 3    0       2017          0        4           NaN         NaN  NaN  NaN
# 4    0       2017          0        4           NaN         NaN  NaN  NaN
# 5    0       2017          0        4           NaN         NaN  NaN  NaN
#
#   drive_node
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
#
# [6 rows x 35 columns]

# %%
project.roadway_changes.columns
# Out:
# Index(['OBJECT', 'OPERATION', 'GROUP', 'A', 'B', 'shstGeometryId', 'name',
#        'roadway', 'drive_access', 'walk_access', 'bike_access', 'county',
#        'model_link_id', 'rail_only', 'bus_only', 'centroidconnect',
#        'assign_group', 'roadway_class', 'area_type', 'bike', 'walk',
#        'MNPASS_CODE', 'MNPASS_PAY', 'managed', 'distance', 'mpo', 'AADT',
#        'count_year', 'segment_id', 'lanes_AM', 'model_node_id', 'osm_node_id',
#        'X', 'Y', 'drive_node'],
#       dtype='object')

# %%
project.card_data
# Out:
# {'project': 'testedit_1',
#  'changes': [{'roadway_property_change': {'property_changes': {'rail_only': {'existing': False,
#       'set': True},
#      'lanes': {'existing': 1, 'set': 4},
#      'bus_only': {'existing': False, 'set': True}},
#     'facility': {'links': {'model_link_id': [428593,
#        719450,
#        271161,
#        1052565,
#        263379,
#        712909],
#       'modes': ['any']}}}}]}

# %%
project.write_project_card(card_file_name)
